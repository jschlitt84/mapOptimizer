# %% [markdown]
# # Resource Allocation Distance Optimizer v2

# %% [markdown]
# ### The goal of this program is to find locations for a finite set of resources such that the minimal mean distance from resource to population member is achieved without leaving any members at an excessive distance from the nearest resource.

# %%
from random import randint, sample, random, choice, uniform
from numpy import mean, std, zeros, average, array, ones, arange
from copy import deepcopy
from math import ceil, sqrt
from geopy.distance import great_circle, vincenty
from geopy import geocoders
from mpl_toolkits.axes_grid1 import make_axes_locatable

import networkx as nx
import datetime
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.ticker as ticker

import cPickle

# %matplotlib inline

# %% [markdown]
# ### Animation enabled

# %%
import matplotlib.animation as animation
from IPython.display import HTML

#Animating via tutorial at:
#http://jakevdp.github.io/blog/2013/05/12/embedding-matplotlib-animations/

VIDEO_TAG = """<video width="1024" height="768" controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def display_animation(anim,fileName):
    print "Preparing to render video in notebook..."
    plt.close(anim._fig)
    return HTML(anim_to_html(anim,fileName))

def anim_to_html(anim,fileName):
    fileName = fileName+'.mp4'
    video = open(fileName, "rb").read()
    anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

# %% [markdown]
# ### Experiment Globals

# %%
meanTilt = 0.97 #Score = tilt* mean distance + (1-tilt)* max distance
figSize = 10
nResource = 7

cfg = {'travel':'network',
           'distance':'manhattan',
           'population':'density',
           'obstacles':0.2,
           'extras':dict(),
           'precision':'int',
           'penalty':300,
           'wander':8,
           'inCityD':True,
           'inCityH':True,
           'threads':1,
           'landFill':1,
           'walkingSpeed':2,
           'roadLimit':1.1,
           'roadTimes':[0.5,0.3,0.1],
           'roads':3,
           'permanent':False,
           'pickledRun':'network.pickle',
           'pickledDist':'network.pickle',
           'resourceFile':False,
           'populationFile':'SELiberiaFiles/population.txt',
           'roadFile':'SELiberiaFiles/network.txt',
           'exclusionFile':'SELiberiaFiles/candidates.txt',
           'useDB':'EbolaMonroviaFull',
           'filterAccessible':False,
           'trimRadius':20,
           'sparsifyX':False,
           'sparsifyY':False,
           'sparsifyLimit':1,
           'distMethod':'reverse',
           'connectSolitary':True}

cfg['extras'] = {'permanent':[]}

cfg['pickledRun'] = False
cfg['pickledDist'] = False
#cfg['resourceFile']='SELiberiaFiles/hospitals.txt',


#Travel modes = crow or path
#Population modes = density or discrete
#Obstacles = odds of obstructed point on network map

# %% [markdown]
# ### Import Data from GIS Source

# %%
fromFile = False

def importFile(ref,mapper = 'null',limit='null'):
    paramDict = dict()
    fileIn = open(ref)
    content = [line.replace('\n','').replace('\t',' ').replace('\r','').replace('  ',' ') for line in fileIn.readlines()]
    fileIn.close()
    dLen = max([len(line.split(' ')) for line in content])
    params = [entry for entry in content if len(entry.split(' ')) < (.5*dLen)]
    entries = [entry.split(' ') for entry in content if len(entry) >= (.5*dLen)]
    entries = [[entry for entry in row if entry != ''] for row in entries]
    for i in range(len(params)):
        entry = params[i].replace('\t',' ')
        while '  ' in entry:
            entry = entry.replace('  ', ' ')
        temp = entry.split(' ')
        try:
            paramDict[temp[0]] = float(temp[1])
        except:
            try:
                paramDict[temp[0]] = temp[1]
            except:
                None
    xLen = len(entries)
    yLen = len(entries[0])
    print 'x:',xLen,'y:',yLen
    print paramDict
    if mapper != 'null':
        try:
            entries = [[mapper[entry] for entry in row] for row in reversed(entries)]
        except:
            entries = [[mapper[float(entry)] for entry in row] for row in reversed(entries)]
    else:
        entries = [[float(entry) for entry in row] for row in reversed(entries)]
    if limit != 'null':
        for x in range(xLen):
            for y in range(yLen):
                if entries[x][y]<limit:
                    entries[x][y] = 0
    return entries,paramDict


if cfg['resourceFile'] != False or cfg['populationFile'] != False or cfg['roadFile'] != False:
    fromFile = True
    roadMapper = {-9999.0:-1,1:0.0666} #60mph hwy, 20mph local, 2mph offroad
    roads,temp = importFile(cfg['roadFile'],mapper=roadMapper)
    population,temp = importFile(cfg['populationFile'],limit=2)
    cfg['extras']['exclude'],temp = importFile(cfg['exclusionFile'])
    resourceList = []
    if cfg['resourceFile'] != False:
        resources = importFile(cfg['resourceFile'])
        for x in range(xSize):
            for y in range(ySize):
                if resources[x][y] != 0:
                    resourceList.append([x,y])
    print "Number of resources:",len(resourceList)
    cfg['xSize'] = xSize = len(population)
    cfg['ySize'] = ySize = len(population[0])
    cfg['geo'] = temp
    
print "From file:", fromFile
# Out:
# x: 259 y: 284
# {'ncols': 284.0, 'cellsize': 0.00833333333333, 'nrows': 259.0, 'xllcorner': -9.741109753912, 'yllcorner': 4.350000000048, 'NODATA_value': -9999.0}
# x:
#  259 y: 284
# {'ncols': 284.0, 'cellsize': 0.0083333333333299, 'nrows': 259.0, 'xllcorner': -9.741109753912, 'yllcorner': 4.350000000048, 'NODATA_value': -9999.0}
# x:
#  259 y: 284
# {'ncols': 284.0, 'cellsize': 0.0083333333333299, 'nrows': 259.0, 'xllcorner': -9.741109753912, 'yllcorner': 4.350000000048, 'NODATA_value': -9999.0}
# Number of resources: 0
# From file: True

# %% [markdown]
# ### Geospatial edge weighting via Vincenty Algorithm

# %%
def getWeight(pt1,pt2):
    return vincenty(pt1,pt2).miles
                        
def ptToCoords(pt,cfg):
    x = pt[1]; y = pt[0]
    cellSize = cfg['geo']['cellsize']
    xP = cfg['geo']['xllcorner']+cellSize*x
    yP = cfg['geo']['yllcorner']+cellSize*y
    return [yP,xP]

def placeEdge(cfg,pt1,pt2,speed,network):
    distance = getWeight(ptToCoords(pt1,cfg),ptToCoords(pt2,cfg))
    time = distance/(cfg['walkingSpeed']/speed)
    if network != 'null':
        network.add_edge(str(pt1),str(pt2),weight = time)
        return network
    return time

# %%
#Testing & Debugging output
def getMaxDist(cfg):
    cellsize = cfg['geo']['cellsize']
    x1 = cfg['geo']['xllcorner']
    y1 = cfg['geo']['yllcorner']
    x2 = xllcorner + cfg['geo']['ncols']*cellsize
    y2 = yllcorner + cfg['geo']['nrows']*cellsize
    dists = [great_circle((y1,x1),(y1+c,x1)).miles,
             great_circle((y1,x1),(y1,x1+c)).miles,
             great_circle((y2,x1),(y2-c,x1)).miles,
             great_circle((y2,x1),(y2,x1+c)).miles]
    maxima = max(dists)
    print "Corner distances found:",dists
    print "Callibration maxima:",maxima
    return maxima
    
#cfg['geo']['maxDist'] = getMaxDist(cfg)

print placeEdge(cfg,[0,0],[1,0],1,'null')
print placeEdge(cfg,[0,0],[0,1],1,'null')
# Out:
# 0.286298527417
# 0.287386632403

# %% [markdown]
# ### Population, Obstacle, and Resource Location Generation

# %%
cfg['extras']['permanent'] = []
        
#Extract pts from matrix
def extract(matrix,minV,maxV):
    listed = []
    for x in range(len(matrix)):
        for y in range(len(matrix[0])):
            if matrix[x][y]>minV and matrix[x][y]<maxV:
                listed.append([x,y])
    return listed        
        
#If population stored by density, creates density matrix
if cfg['population'] == 'density' and not fromFile:
    cfg['extras']['occupied'] = pLocs
    temp = zeros((size,size))
    for i in range(nPopulation):
        temp[pLocs[i][0]][pLocs[i][1]] += random()
    pLocs = temp
elif not fromFile:
    cfg['extras']['occupied'] = pLocs

    
#Extracting point lists from matrices   
if cfg['travel'] == 'network' and fromFile:
    cfg['extras']['lakes'] = roads
    pLocs = population
    cfg['extras']['occupied'] = extract(pLocs,0,99999999)
    if cfg['resourceFile'] != False:
        cfg['extras']['permanent'] = extract(resources,0,999) 
    

#Calculating neighbors if hill climber constrained to populated points    
if cfg['inCityH']:
    neighbors = []
    for i in cfg['extras']['occupied']:
        d = cfg['wander'] + 1
        x = i[0]
        y = i[1]
        accessible = []
        for xP in range(x-d,x+d):
            for yP in range(x-d,y+d):
                try:
                    if cfg['extras']['lakes'][xP][yP] != -1:
                        accessible.append([xP,yP])
                except:
                    None
        if cfg['exclusionFile'] != False:
            accessible = [loc for loc in accessible if cfg['extras']['exclude'][loc[0]][loc[1]] == 1]
        neighbors.append(deepcopy(accessible))
        
    cfg['extras']['neighbors'] = neighbors


if cfg['inCityD']:
    cfg['extras']['postExclusion'] = [loc for loc in cfg['extras']['occupied'] if cfg['extras']['exclude'][loc[0]][loc[1]] == 1]
    
if cfg['resourceFile'] != False:
    print "Fixed resources:",extract(resources,0,999)
else:
    print "No fixed resources found"
# Out:
# No fixed resources found

# %%
#Removing inaccessible locations
if cfg['filterAccessible']:
    print "Population filtered by road accessibility"
    cfg['extras']['occupied'] = [i for i in cfg['extras']['occupied'] if cfg['extras']['lakes'][i[0]][i[1]] != -1]
#Add low speed roads to occupied pts
else:
    print "Speed 1 road network added to populated areas"
    for i in cfg['extras']['occupied']:
        if cfg['extras']['lakes'][i[0]][i[1]] == -1:
            cfg['extras']['lakes'][i[0]][i[1]] = 1
# Out:
# Speed 1 road network added to populated areas

# %%
#Scatters initial set of resources
rLocs = [[randint(0,cfg['xSize']-1),randint(0,cfg['ySize']-1)] for x in range(nResource)]

# %% [markdown]
# ### Network Population Function for Manhattan Distance Travel

# %%
def getNetwork(cfg,size):
    """Generates Network for Manhattan Distance Travel"""
    network=nx.Graph()
    try:
        xSize = cfg['xSize']
    except:
        xSize = size
    try:
        ySize = cfg['ySize']
    except:
        ySize = size

    for x in range(xSize-1):
        for y in range(ySize):
            if cfg['extras']['lakes'][x+1][y] != -1 and cfg['extras']['lakes'][x][y] != -1:
                weight = max([cfg['extras']['lakes'][x+1][y],cfg['extras']['lakes'][x][y]])
                network = placeEdge(cfg,[x+1,y],[x,y],weight,network)
                #network.add_edge(str([x+1,y]),str([x,y]),weight = weight)
    for x in range(xSize):
        for y in range(ySize-1):
            if cfg['extras']['lakes'][x][y+1] != -1 and cfg['extras']['lakes'][x][y] != -1:
                weight = max([cfg['extras']['lakes'][x][y+1],cfg['extras']['lakes'][x][y]])
                network = placeEdge(cfg,[x,y+1],[x,y],weight,network)
                #network.add_edge(str([x,y+1]),str([x,y]),weight = weight)
                
    if cfg['roads'] >= 0: 
        roadV = cfg['roadLimit']
        for x in range(xSize-1):
            for y in range(ySize-1):
                if cfg['extras']['lakes'][x][y] != -1 and cfg['extras']['lakes'][x+1][y+1] != -1:
                    if cfg['extras']['lakes'][x][y] < roadV and cfg['extras']['lakes'][x+1][y+1] < roadV:
                        weight = max([cfg['extras']['lakes'][x][y],cfg['extras']['lakes'][x+1][y+1]])
                        network = placeEdge(cfg,[x,y],[x+1,y+1],weight*1.41421356237,network)
                        #network.add_edge(str([x,y]),str([x+1,y+1]),weight = weight*1.41421356237)
        for x in range(1,xSize):
            for y in range(ySize-1):
                if cfg['extras']['lakes'][x][y] != -1 and cfg['extras']['lakes'][x-1][y+1] != -1: 
                    if cfg['extras']['lakes'][x][y] < roadV and cfg['extras']['lakes'][x-1][y+1] < roadV:
                        weight = max([cfg['extras']['lakes'][x][y],cfg['extras']['lakes'][x-1][y+1]])
                        network = placeEdge(cfg,[x,y],[x-1,y+1],weight*1.41421356237,network)
                        #network.add_edge(str([x,y]),str([x-1,y+1]),weight = weight*1.41421356237)
                
    return network


cfg['extras']['network'] = getNetwork(cfg,0)
#nx.draw(cfg['extras']['network'])

# %% [markdown]
# ### Sparsify function reduces resolution for nodes below a reachability threshold for high resolution runs

# %%
def sparsify(network,cfg,pLocs,size,rLocs):
    limit = cfg['sparsifyLimit']
    newNet = deepcopy(network)
    try:
        xSize = cfg['xSize']
    except:
        xSize = size
    try:
        ySize = cfg['ySize']
    except:
        ySize = size

    destinations = rLocs + cfg['extras']['permanent']
    if cfg['sparsifyX']:
        for x in range(0,xSize-1,2):
            for y in range(ySize):
                if cfg['extras']['lakes'][x][y]>=limit and cfg['extras']['lakes'][x+1][y]>=limit and [x+1,y] not in destinations:
                    try:
                        newNet.remove_node(str([x+1,y]))
                        cfg['extras']['lakes'][x+1][y] = -1
                        pLocs[x][y] += pLocs[x+1][y]
                        pLocs[x+1][y] = 0
                        #print "removing x node",x,y
                    except:
                        None
                    try:
                        #print "adding x edge",x,y,x+2,y
                        weight = max(cfg['extras']['lakes'][x][y],cfg['extras']['lakes'][x+2][y])
                        newNet.add_edge(str([x,y]),str([x+2,y]),weight = 2*weight)
                    except:
                        None
        print "X Sparsification complete"
    if cfg['sparsifyY']:
        for x in range(xSize):
            for y in range(0,ySize-1,2):
                if cfg['extras']['lakes'][x][y]>=limit and cfg['extras']['lakes'][x][y+1]>=limit and [x,y+1] not in destinations:
                    try:
                        newNet.remove_node(str([x,y+1]))
                        cfg['extras']['lakes'][x][y+1] = -1
                        pLocs[x][y] += pLocs[x][y+1]
                        pLocs[x][y+1] = 0
                        #print "removing y node",x,y
                    except:
                        None
                    try:
                        #print "adding y edge",x,y,x,y+2
                        weight = max(cfg['extras']['lakes'][x][y],cfg['extras']['lakes'][x][y+2])
                        newNet.add_edge(str([x,y]),str([x,y+2]),weight = 2*weight)
                    except:
                        None
        print "Y Sparsification complete"
    occupied = extract(pLocs,0,99999)
    return newNet,pLocs,occupied,cfg['extras']['lakes']
            
if cfg['sparsifyY'] or cfg['sparsifyY']:      
    cfg['extras']['network'],pLocs,cfg['extras']['occupied'],cfg['extras']['lakes'] = sparsify(netTemp,cfg,pLocs,0,rLocs)

# %%
def getKey(key1,key2):
    pt1 = key1
    pt2 = listFromStr(key2)
    return str(rank(pt1[0],pt1[1],pt2[0],pt2[1]))

def listFromStr(text):
    return [int(entry) for entry in list(text.replace('[','').replace(']','').replace('(','').replace(')','').split(','))]

# %% [markdown]
# ### Prioritizes Points to Reduce Redundancy

# %%
def rank(x1,y1,x2,y2):
    if x1 < x2:
        return x1,y1,x2,y2
    elif x1 > x2:
        return x2,y2,x1,y1
    elif y1 < y2:
        return x1,y1,x2,y2
    else:
        return x2,y2,x1,y1

# %% [markdown]
# ### Reverse Lookup Method, find all distances to a give resource location

# %%
def reverseLookup(cfg,rLocs,pLocs,call='null'):
    try:
        last = cfg['extras']['last']
    except:
        last = dict()
    distances = dict()
    data = []
    weights = []
    destinations = rLocs+cfg['extras']['permanent']
    destStrings = []
    for pt in destinations:
        key = str(pt)
        try:
            distances[key] = last[key]
            destStrings.append(key)
        except:
            try:
                distances[key] = nx.single_source_dijkstra_path_length(cfg['extras']['network'],key)
                destStrings.append(key)
            except:
                None
                #print pt, "appears to be solitary"
    if call == 'null':
        for pt in cfg['extras']['occupied']:
            trips = set()
            key = str(pt)
            for dest in destStrings:
                try:
                    trips.add(distances[dest][key])
                except:
                    None
            if len(trips) != 0:
                data.append(min(trips))
                weights.append(pLocs[pt[0]][pt[1]])
        cfg['extras']['last'] = destinations
        return data, weights
    elif call == 'plot':
        distMap = zeros((xSize,ySize))
        ptRefs = dict()
        for pt in cfg['extras']['occupied']:
            trips = set()
            key = str(pt)
            for dest in destStrings:
                try:
                    trips.add(distances[dest][key])
                except:
                    None
            if len(trips) != 0:
                ptRefs[str(pt)] = min(trips)
        #print ptRefs.items()
        cfg['extras']['last'] = destinations
        for key,value in ptRefs.iteritems():
            pt = listFromStr(key)
            distMap[pt[0]][pt[1]] = value
        return distMap

# %% [markdown]
# ### Worker Functions

# %%
def getPts(locs):
    """Converts pt list to plotable format"""
    ptsX = [pt[0] for pt in locs]
    ptsY = [pt[1] for pt in locs]
    return ptsX,ptsY

# %%
def getStats(pLocs,rLocs,cfg):
    """Return distance stats"""
    if cfg['threads'] != 1:
        mgr = Manager(); cfgP = mgr.dict(cfg)
        out_q = Queue()
        
        block = int(ceil(len(cfg['extras']['occupied'])/float(cfg['threads'])))
        processes = []; distances = []

        for i in range(cfg['threads']):
            p = Process(target = statsProc, args = (pLocs,rLocs,cfgP,i,cfg['extras']['occupied'][block*i:block*(i+1)],out_q))
            processes.append(p)
            p.start()
            merged = {}
        for i in range(cfg['threads']):
            merged.update(out_q.get())
        for p in processes:
            p.join()
        for i in range(cfg['threads']):
            distances += merged[i]
        cfg = dict(cfgP.items())
            
    else:
        if cfg['distMethod'] != 'reverse':
            distances = [getClosest(pt,rLocs,cfg) for pt in cfg['extras']['occupied']]
        else:
            distances,weights = reverseLookup(cfg,rLocs,pLocs)
        
    if cfg['population'] == 'discrete':
        return {'max':max(distances),
                'min':min(distances),
                'mean':mean(distances),
                'std':std(distances)}
    else:
        if cfg['distMethod'] != 'reverse':
            weights = [pLocs[pt[0]][pt[1]] for pt in cfg['extras']['occupied']]
        mean = average(distances, weights=weights)
        return {'max':max(distances),
                'min':min(distances),
                'mean':mean,
                'std':pow(average((distances-mean)**2, weights=weights),0.5)}

# %% [markdown]
# ### Plot Generation

# %%
def mapTransparency(grid,coloredGrid,alphaPow):
    temp = deepcopy(coloredGrid)
    maxVal = max([max(row) for row in grid])
    for i in range(len(temp)):
        for j in range(len(temp[0])):
            
            temp[i][j][3] = pow((float(grid[i][j])/maxVal),alphaPow)
    return temp


def mapColors(grid,level,cmap):
    cNorm = colors.Normalize(vmin=0, vmax=level)
    scalarMap = cm.ScalarMappable(norm=cNorm, cmap=cmap)
    if type(grid) is list:
        temp = array(grid).tolist()
    else:
        temp = grid.tolist()
    for x in range(len(grid)):
        for y in range(len(grid[0])):
            temp[x][y] = list(scalarMap.to_rgba(float(grid[x][y])))
    return temp


def ptsToText(pts,cfg,precision = 10):
    locStrings = []
    gCoder = geocoders.GoogleV3()
    for pt in pts:
        coord = ptToCoords(pt,cfg)
        try:
            place, (lat,lon) = gCoder.geocode("%s,%s" % (coord[0],coord[1]))
        except:
            place = 'Unknown Road'
        locStrings.append('%s : {%s, %s}' % (place,str(coord[0])[0:precision],str(coord[1])[0:precision]))
    return locStrings


def pltLocs(pLocs,rLocs,cfg,stats='null',
            title='null',
            call='null',
            cmap ='Greys_r', 
            cmap2 = 'autumn_r',
            transpose = True,
            popAlpha = 1,
            alphaPow = 0.2,
            distMap = True):
    if call == 'animate' or call == 'final':
        plt.clf()
        spacer = '\n\n'
        xNudge = -.05
        yNudge = 0.87
        #fig = plt.figure(figsize=(15,15))
    else:
        fig = plt.figure(figsize=(15,15))
        spacer = ' '*7
        xNudge = -0.05
        yNudge = 1.005


    ax1 = plt.subplot(221)
    if cfg['travel'] == 'network':
        plt.imshow(cfg['extras']['lakes'],cmap=cmap,interpolation='nearest',alpha =0.7)
        plt.xlim(0,len(cfg['extras']['lakes'][0]))
        plt.ylim(0,len(cfg['extras']['lakes']))
    else:
        plt.xlim(0,max([entry[0] for entry in cfg['extra']['occupied']]))
        plt.ylim(0,max([entry[1] for entry in cfg['extra']['occupied']]))
    if cfg['population'] == 'discrete':
        pX,pY = getPts(pLocs)
        plt.scatter(pY,pX, s=2, c='black', alpha=0.25)
    elif call != 'final' and call != 'finalOut':
        colorized = mapColors(pLocs,1,cmap2)
        colorized = mapTransparency(pLocs,colorized,alphaPow)
        plt.imshow(colorized,cmap=cmap2,interpolation='nearest',zorder=2,alpha = popAlpha)
    if call != 'final':
        plt.title("Regional Population Density and Travel Network",size=12)
    else:
        plt.title("Regional Travel Network",size=12)
        
    xTicks = arange(0,cfg['geo']['ncols'],25)
    yTicks = arange(0,cfg['geo']['nrows'],25)
    xLabels = [str(ptToCoords([0,pt],cfg)[1])[0:7] for pt in xTicks]
    yLabels = [str(ptToCoords([pt,0],cfg)[0])[0:7] for pt in yTicks]
    plt.xticks(xTicks, xLabels,rotation=45,size=10)
    plt.yticks(yTicks, yLabels,size=10)
    plt.grid(True)
    
        
    rX,rY = getPts(rLocs)
    plt.scatter(rY,rX, s=250, zorder=3, c = 'none')
    plt.scatter(rY,rX, s=250, c='red', zorder=3, alpha = .5)
    
    bX,bY = getPts(cfg['extras']['permanent'])
    plt.scatter(bY,bX, s=250, zorder=3, c = 'none')
    plt.scatter(bY,bX, s=250, c='blue', zorder=3, alpha = .5)
    
    
    ax2 = plt.subplot(222)
    if distMap:
        plt.imshow(reverseLookup(cfg,rLocs,pLocs,call='plot'),origin='lower')
    plt.title("Expected Travel Time by Region",size = 12)
    plt.xticks(xTicks, xLabels,rotation=45,size=10)
    yLabels = ['' for pt in yTicks]
    plt.yticks(yTicks, yLabels,size=10)
    plt.grid(True)
    
    
    if call == 'final' or call == 'finalOut':
        for x, y, in zip(rY, rX):
            try:
                ax1.annotate(ptsToText([[x,y]],cfg,precision = 7)[0], 
                xy = (x, y), xytext = (-20, 20),
                textcoords = 'offset points', ha = 'left', va = 'bottom',
                bbox = dict(boxstyle = 'round,pad=0.4', fc = 'yellow', alpha = 0.8),
                arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'),
                zorder = 100)
                ax2.texts.append(ax1.texts.pop())
            except:
                None
            plt.suptitle('%s Resource Final Results' % nResource,fontsize =18,y=yNudge)
    
    if call != 'animate' and call != 'final':
        plt.tight_layout()
    else:
        None
        #plt.subplots_adjust(wspace=0.02)
    
    if title != 'null' and call != 'final' and call != 'finalOut':
        plt.suptitle(title,fontsize =18,y=yNudge)
    if stats != 'null':
        plt.xlabel('Mean Travel Time (hrs): %s%sMax Travel Time: %s%sStd Dev: %s' % (stats['mean'],spacer,stats['max'],spacer,stats['std']),
                   x=xNudge,size=14)
    if call != 'animate' and call != 'final':
        plt.show()
    return plt

# %% [markdown]
# ### Starting Conditions

# %%
stats  = {'mean':0,'max':0,'std':0}
pltLocs(pLocs,rLocs,cfg,title = 'Starting Conditions',popAlpha = 1, alphaPow = .25, stats= stats)
# Out:
# <module 'matplotlib.pyplot' from '/Library/Python/2.7/site-packages/matplotlib/pyplot.pyc'>

# %% [markdown]
# ### Denaturing Algorithm

# %%
def denature(pLocs,rLocs,meanTilt,cfg,
             tracker=[],
             stopLimit = 50,
             timeLimit = 20000,
             showEvery = 25,
             best = 10000000,
             bestStats=dict()):
    
    """Randomly replaces 1 to n/2 resource locations and keeps if new solution scores better"""
    n = len(rLocs)
    gen = 0
    scores = []
    bestStats = dict()
    t1 = datetime.datetime.now()
    while len(scores)<stopLimit or len(set(scores[-stopLimit:])) != 1:
        newLocs = deepcopy(rLocs)
        ids = sample(range(n),randint(1,int(n/2.+.5)))
        for x in ids:
            if cfg['inCityD']:
                loc = choice(cfg['extras']['postExclusion'])
            else:
                loc = [randint(0,cfg['xSize']-1),randint(0,cfg['ySize']-1)]
            newLocs[x] = loc
        stats = getStats(pLocs,newLocs,cfg)
        score = stats['mean']*meanTilt + stats['max']*(1-meanTilt)
        if best > score:
            rLocs = deepcopy(newLocs); bestStats = deepcopy(stats)
            best = score
            tracker.append({'gen':'Denature %s' % gen,'score':score,'stats':deepcopy(stats),'pts':deepcopy(rLocs)})
        if gen%showEvery == 0:
            print "Best: %s   Uni: %s   Gen: %s   Mean: %s   Max: %s   Std: %s   Time: %s" % (best,
                                                                   len(set(scores[-stopLimit:])),
                                                                   gen,bestStats['mean'],
                                                                   bestStats['max'],
                                                                   bestStats['std'],
                                                                   (datetime.datetime.now()-t1).seconds)
        if gen%(showEvery*20) == 0:
            pltLocs(pLocs,rLocs,cfg,bestStats,title='Denaturer Gen %s Optimal Placement' % gen,cmap='Greys_r',cmap2='autumn_r')
        if gen == timeLimit:
            break
        scores.append(best)
        gen += 1
    if gen == timeLimit:
        print "\nGeneration limit reached after %s generations" % timeLimit
    else:
        print "\nStable solution found at generation %s and maintained for %s generations" % (gen-stopLimit,stopLimit)
    pltLocs(pLocs,rLocs,cfg,bestStats,title='Gen %s Optimal Placement' % gen,cmap='Greys_r',cmap2='autumn_r')
    print len(tracker), "improvements made"
    return rLocs,tracker,best,bestStats

# %% [markdown]
# ### Hill Climber Algorithm

# %%
def climb(pLocs,rLocs,meanTilt,cfg,
             tracker=[],
             stopLimit = 50,
             timeLimit = 20000,
             showEvery = 25,
             best = 10000000,
             bestStats=dict()):
    """Randomly nudges 1 to n/2 resources locations and keeps if new solution is better"""
    n = len(rLocs)
    gen = 0
    scores = []
    t1 = datetime.datetime.now()
    while len(scores)<stopLimit or len(set(scores[-stopLimit:])) != 1:
        newLocs = deepcopy(rLocs)
        ids = sample(range(n),randint(1,int(n/2.+.5)))
        for x in ids:
            if cfg['inCityH']:
                loc = choice(cfg['extras']['neighbors'][x])
            else:
                loc = [rLocs[x][0]+randint(-cfg['wander'],cfg['wander']),rLocs[x][1]+randint(-cfg['wander'],cfg['wander'])]
            newLocs[x] = loc
        stats = getStats(pLocs,newLocs,cfg)
        score = stats['mean']*meanTilt + stats['max']*(1-meanTilt)
        if best > score:
            rLocs = deepcopy(newLocs); bestStats = deepcopy(stats)
            best = score
            tracker.append({'gen':'Hill Climber %s' % gen,'score':score,'stats':deepcopy(stats),'pts':deepcopy(rLocs)})
        if gen%showEvery == 0:
            print "Best: %s   Uni: %s   Gen: %s   Mean: %s   Max: %s   Std: %s   Time: %s" % (best,
                                                                   len(set(scores[-stopLimit:])),
                                                                   gen,bestStats['mean'],
                                                                   bestStats['max'],
                                                                   bestStats['std'],
                                                                   (datetime.datetime.now()-t1).seconds)
        if gen%(showEvery*20) == 0:
            pltLocs(pLocs,rLocs,cfg,bestStats,title='Hill Climber Gen %s Optimal Placement' % gen,cmap='Greys_r',cmap2='autumn_r')
        if gen == timeLimit:
            break
        scores.append(best)
        gen += 1
    if gen == timeLimit:
        print "\nGeneration limit reached after %s generations" % timeLimit
    else:
        print "\nStable solution found at generation %s and maintained for %s generations" % (gen-stopLimit,stopLimit)
    pltLocs(pLocs,rLocs,cfg,bestStats,title='Gen %s Optimal Placement' % gen,cmap='Greys_r',cmap2='autumn_r')
    print len(tracker), "improvements made"    
    return rLocs,tracker,best,bestStats

# %% [markdown]
# ### Experiment Results

# %%
#Denature until stable solution is maintained for 30000 generations
stagnantLimit = 2000
best = 10000000
showEvery = 50
cfg['threads'] = 1

rLocs,tracker,best,bestStats = denature(pLocs,rLocs,meanTilt,cfg,
                              stopLimit = stagnantLimit,
                              timeLimit = 'null',
                              showEvery = showEvery,
                              best = best)
# Out:
# Best: 2.841267196   Uni: 0   Gen: 0   Mean: 2.56875555017   Max: 11.6524770776   Std: 1.26699718118   Time: 1
# Best: 1.58673892462   Uni: 9   Gen: 50   Mean: 1.325587025   Max: 10.0306503456   Std: 0.962267879118   Time: 153
# Best: 1.58673892462   Uni: 9   Gen: 100   Mean: 1.325587025   Max: 10.0306503456   Std: 0.962267879118   Time: 286
# Best: 1.58169708224   Uni: 10   Gen: 150   Mean: 1.3120797222   Max: 10.2993250566   Std: 1.02864622402   Time: 420
# Best: 1.53008496136   Uni: 12   Gen: 200   Mean: 1.25950585425   Max: 10.2788094247   Std: 1.05326362142   Time: 548
# Best: 1.52956490346   Uni: 13   Gen: 250   Mean: 1.25896971209   Max: 10.2788094247   Std: 1.03059672096   Time: 669
# Best: 1.52956490346   Uni: 13   Gen: 300   Mean: 1.25896971209   Max: 10.2788094247   Std: 1.03059672096   Time: 789
# Best: 1.48982712565   Uni: 16   Gen: 350   Mean: 1.21800293083   Max: 10.2788094247   Std: 1.07382149706   Time: 909
# Best: 1.47600183025   Uni: 19   Gen: 400   Mean: 1.20375004897   Max: 10.2788094247   Std: 1.07863814169   Time: 1029
# Best: 1.47600183025   Uni: 19   Gen: 450   Mean: 1.20375004897   Max: 10.2788094247   Std: 1.07863814169   Time: 1149
# Best: 1.47393049832   Uni: 20   Gen: 500   Mean: 1.20161465523   Max: 10.2788094247   Std: 1.03839499527   Time: 1268
# Best: 1.47320033676   Uni: 21   Gen: 550   Mean: 1.21915297083   Max: 9.68739850167   Std: 1.04326185187   Time: 1388
# Best: 1.46969669658   Uni: 22   Gen: 600   Mean: 1.20607547731   Max: 9.99344945298   Std: 1.00452112111   Time: 1508
# Best: 1.45935918611   Uni: 23   Gen: 650   Mean: 1.2043356099   Max: 9.70512148357   Std: 1.02307610695   Time: 1632
# Best: 1.45935918611   Uni: 23   Gen: 700   Mean: 1.2043356099   Max: 9.70512148357   Std: 1.02307610695   Time: 1755
# Best: 1.45935918611   Uni: 23   Gen: 750   Mean: 1.2043356099   Max: 9.70512148357   Std: 1.02307610695   Time: 1876
# Best: 1.45828357548   Uni: 24   Gen: 800   Mean: 1.20322673296   Max: 9.70512148357   Std: 1.01999545785   Time: 1996
# Best: 1.4316919079   Uni: 25   Gen: 850   Mean: 1.17636077613   Max: 9.68739850167   Std: 0.972225897416   Time: 2117
# Best: 1.4316919079   Uni: 25   Gen: 900   Mean: 1.17636077613   Max: 9.68739850167   Std: 0.972225897416   Time: 2238
# Best: 1.4316919079   Uni: 25   Gen: 950   Mean: 1.17636077613   Max: 9.68739850167   Std: 0.972225897416   Time: 2359
# Best: 1.4316919079   Uni: 25   Gen: 1000   Mean: 1.17636077613   Max: 9.68739850167   Std: 0.972225897416   Time: 2482
# Best: 1.4316919079   Uni: 25   Gen: 1050   Mean: 1.17636077613   Max: 9.68739850167   Std: 0.972225897416   Time: 2626
# Best: 1.4316919079   Uni: 25   Gen: 1100   Mean: 1.17636077613   Max: 9.68739850167   Std: 0.972225897416   Time: 2747
# Best: 1.42470527029   Uni: 26   Gen: 1150   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 2865
# Best: 1.42470527029   Uni: 26   Gen: 1200   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 2982
# Best: 1.42470527029   Uni: 26   Gen: 1250   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 3109
# Best: 1.42470527029   Uni: 26   Gen: 1300   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 3233
# Best: 1.42470527029   Uni: 26   Gen: 1350   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 3355
# Best: 1.42470527029   Uni: 26   Gen: 1400   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 3478
# Best: 1.42470527029   Uni: 26   Gen: 1450   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 3601
# Best: 1.42470527029   Uni: 26   Gen: 1500   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 3723
# Best: 1.42470527029   Uni: 26   Gen: 1550   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 3848
# Best: 1.42470527029   Uni: 26   Gen: 1600   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 3972
# Best: 1.42470527029   Uni: 26   Gen: 1650   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 4095
# Best: 1.42470527029   Uni: 26   Gen: 1700   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 4218
# Best: 1.42470527029   Uni: 26   Gen: 1750   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 4342
# Best: 1.42470527029   Uni: 26   Gen: 1800   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 4465
# Best: 1.42470527029   Uni: 26   Gen: 1850   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 4591
# Best: 1.42470527029   Uni: 26   Gen: 1900   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 4715
# Best: 1.42470527029   Uni: 26   Gen: 1950   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 4840
# Best: 1.42470527029   Uni: 26   Gen: 2000   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 4966
# Best: 1.42470527029   Uni: 18   Gen: 2050   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 5114
# Best: 1.42470527029   Uni: 18   Gen: 2100   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 5241
# Best: 1.42470527029   Uni: 17   Gen: 2150   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 5368
# Best: 1.42470527029   Uni: 15   Gen: 2200   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 5492
# Best: 1.42470527029   Uni: 14   Gen: 2250   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 5619
# Best: 1.42470527029   Uni: 14   Gen: 2300   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 5744
# Best: 1.42470527029   Uni: 11   Gen: 2350   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 5874
# Best: 1.42470527029   Uni: 8   Gen: 2400   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 6001
# Best: 1.42470527029   Uni: 8   Gen: 2450   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 6127
# Best: 1.42470527029   Uni: 7   Gen: 2500   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 6253
# Best: 1.42470527029   Uni: 6   Gen: 2550   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 6377
# Best: 1.42470527029   Uni: 5   Gen: 2600   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 6504
# Best: 1.42470527029   Uni: 4   Gen: 2650   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 6629
# Best: 1.42470527029   Uni: 4   Gen: 2700   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 6756
# Best: 1.42470527029   Uni: 4   Gen: 2750   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 6879
# Best: 1.42470527029   Uni: 3   Gen: 2800   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 7001
# Best: 1.42470527029   Uni: 2   Gen: 2850   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 7126
# Best: 1.42470527029   Uni: 2   Gen: 2900   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 7248
# Best: 1.42470527029   Uni: 2   Gen: 2950   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 7367
# Best: 1.42470527029   Uni: 2   Gen: 3000   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 7488
# Best: 1.42470527029   Uni: 2   Gen: 3050   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 7633
# Best: 1.42470527029   Uni: 2   Gen: 3100   Mean: 1.16915805695   Max: 9.68739850167   Std: 0.972195670366   Time: 7757
# Stable solution found at generation 1143 and maintained for 2000 generations
# 26 improvements made

# %%
"""#Hill climb until stable solution is maintained for 3000 generations
cfg['threads'] = 1
stagnantLimit = 2000

rLocs,tracker,best,bestStats = climb(pLocs,rLocs,meanTilt,cfg,
                              stopLimit = stagnantLimit,
                              timeLimit = 'null',
                              showEvery = showEvery,
                              best = best,
                              bestStats = bestStats,
                              tracker = tracker)"""
# Out:
# "#Hill climb until stable solution is maintained for 3000 generations\ncfg['threads'] = 1\nstagnantLimit = 2000\n\nrLocs,tracker,best,bestStats = climb(pLocs,rLocs,meanTilt,cfg,\n                              stopLimit = stagnantLimit,\n                              timeLimit = 'null',\n                              showEvery = showEvery,\n                              best = best,\n                              bestStats = bestStats,\n                              tracker = tracker)"

# %% [markdown]
# ### Save pickle if ran, load pickle if not

# %%
do = 'save'
try:
    test = tracker
    if len(test) > 1:
        fileOut = open('Tracker%s.pickle' % nResource,'w')
        cPickle.dump(tracker,fileOut)
        fileOut.close()
        print "Saved tracker to file"
    else:
        do = 'load'
except:
    do = 'load'

if do == 'load':
    fileOut = open('Tracker%s.pickle' % nResource)
    tracker = cPickle.load(fileOut)
    fileOut.close()
    rLocs = tracker[-1]['pts']
    stats = tracker[-1]['stats']
    gen = tracker[-1]['gen']
    print "Loaded tracker from file"
# Out:
# Loaded tracker from file

# %% [markdown]
# ### Plot final Results

# %%
pltLocs(pLocs,rLocs,cfg,popAlpha = 1, alphaPow = .25, stats= stats,call='finalOut')
pltLocs(pLocs,rLocs,cfg,title = 'Gen %s Optimal Results' % gen,popAlpha = 1, alphaPow = .25, stats= stats)
# Out:
# <module 'matplotlib.pyplot' from '/Library/Python/2.7/site-packages/matplotlib/pyplot.pyc'>

# %% [markdown]
# ### Animation Generation

# %%
def animateMaps(pLocs,tracker,cfg,cmap='Greys_r',cmap2='autumn_r',interval = 500,fps = 1):
    length = len(tracker) + 1
    #length = 1
    fig = plt.figure(figsize=(12,8.4))
    fig.subplots_adjust(wspace=0.03,hspace=1.8,bottom=-2)

        
    def animate(i):
        print "ANIMATED FRAME", i+1, "OF", length
        if i != length-1:
            pltLocs(pLocs,
                       tracker[i]['pts'],
                       cfg,
                       stats=tracker[i]['stats'],
                       title='Gen %s Optimal Placement' % tracker[i]['gen'],
                       call='animate',
                       cmap=cmap,
                       cmap2=cmap2)
        else:
            pltLocs(pLocs,
                       tracker[i-1]['pts'],
                       cfg,
                       stats=tracker[i-1]['stats'],
                       title='Gen %s Optimal Placement' % tracker[i-1]['gen'],
                       call='final',
                       cmap=cmap,
                       cmap2=cmap2)
    
    anim = animation.FuncAnimation(fig,animate,frames=length,interval=interval, blit=False)
    fileName = 'mapOptimization'
    #print "Generating", fileName, "gif animation"
    #anim.save(fileName+'.gif', writer='imagemagick', fps=fps)
    #sleep(3)
    print "Generating", fileName, "mp4 video"
    writer = animation.writers['ffmpeg'](fps=1)
    anim.save(fileName+str(nResource)+'.mp4',writer=writer,dpi=250)
    print "Complete!"
    return anim,fileName+str(nResource)

# %%
anim,fileName = animateMaps(pLocs,tracker,cfg)
# Out:
# ANIMATED FRAME 1 OF 27
# Generating
#  mapOptimization mp4 video
# ANIMATED FRAME 1 OF 27
# ANIMATED FRAME
#  2 OF 27
# ANIMATED FRAME
#  3 OF 27
# ANIMATED FRAME
#  4 OF 27
# ANIMATED FRAME
#  5 OF 27
# ANIMATED FRAME
#  6 OF 27
# ANIMATED FRAME
#  7 OF 27
# ANIMATED FRAME
#  8 OF 27
# ANIMATED FRAME
#  9 OF 27
# ANIMATED FRAME
#  10 OF 27
# ANIMATED FRAME
#  11 OF 27
# ANIMATED FRAME
#  12 OF 27
# ANIMATED FRAME
#  13 OF 27
# ANIMATED FRAME
#  14 OF 27
# ANIMATED FRAME
#  15 OF 27
# ANIMATED FRAME
#  16 OF 27
# ANIMATED FRAME
#  17 OF 27
# ANIMATED FRAME
#  18 OF 27
# ANIMATED FRAME
#  19 OF 27
# ANIMATED FRAME
#  20 OF 27
# ANIMATED FRAME
#  21 OF 27
# ANIMATED FRAME
#  22 OF 27
# ANIMATED FRAME
#  23 OF 27
# ANIMATED FRAME
#  24 OF 27
# ANIMATED FRAME
#  25 OF 27
# ANIMATED FRAME
#  26 OF 27
# ANIMATED FRAME
#  27 OF 27
# Complete!

# %%
display_animation(anim,fileName)

# %% [markdown]
# # Final Site Selections & Statistics

# %%
for location in sorted(ptsToText(rLocs,cfg,precision = 10)):
    print location
# Out:
# Central Rivercess, Liberia : {5.68333333, -9.5077764}
# Chedepo, Liberia : {5.34166666, -8.0411097}
# Dugbe River, Liberia : {4.92500000, -8.6744430}
# Gwelekpoken, Liberia : {4.83333333, -7.9077764}
# Maryland Avenue, Barrakeh, Liberia : {4.49166666, -7.6661097}
# Plahn Nyarn, Liberia : {5.29166666, -9.0077764}
# Unnamed Road, Zwedru, Liberia : {6.05833333, -8.1411097}

# %%
for key, item in tracker[-1]['stats'].iteritems():
    print "%s: %s" % (key,item)
# Out:
# std: 0.972195670366
# max: 9.68739850167
# mean: 1.16915805695
# min: 0

# %% [raw]
# © 2014 James Schlitt
