# %% [markdown]
# # Resource Allocation Distance Optimizer v2

# %% [markdown]
# ### The goal of this program is to find locations for a finite set of resources such that the minimal mean distance from resource to population member is achieved without leaving any members at an excessive distance from the nearest resource.

# %%
import matplotlib.pyplot as plt
from random import randint, sample, random, choice, uniform
from numpy import mean, std, zeros, average, array
from copy import deepcopy
from numpy.random import rand
from multiprocessing import Process, Queue, cpu_count, Manager
from math import ceil, sqrt

import matplotlib.cm as cm
import networkx as nx
import datetime
import matplotlib.colors as colors
import pymongo as pm

from numpy import ones,vstack
from numpy.linalg import lstsq

import cPickle

# %matplotlib inline

# %% [markdown]
# ### Animation enabled

# %%
import matplotlib.animation as animation
from IPython.display import HTML

#Animating via tutorial at:
#http://jakevdp.github.io/blog/2013/05/12/embedding-matplotlib-animations/

VIDEO_TAG = """<video width="1024" height="768" controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def display_animation(anim,fileName):
    print "Preparing to render video in notebook..."
    plt.close(anim._fig)
    return HTML(anim_to_html(anim,fileName))

def anim_to_html(anim,fileName):
    fileName = fileName+'.mp4'
    video = open(fileName, "rb").read()
    anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

# %% [markdown]
# ### Experiment Globals

# %%
meanTilt = 0.80 #Score = tilt* mean distance + (1-tilt)* max distance
figSize = 10
nResource = 5

cfg = {'travel':'network',
           'distance':'manhattan',
           'population':'density',
           'obstacles':0.2,
           'extras':dict(),
           'precision':'int',
           'penalty':300,
           'wander':3,
           'inCityD':True,
           'inCityH':False,
           'threads':1,
           'landFill':1,
           'roadLimit':1.1,
           'roadTimes':[0.5,0.3,0.1],
           'roads':3,
           'permanent':False,
           'pickledRun':'network.pickle',
           'pickledDist':'network.pickle',
           'resourceFile':False,
           'populationFile':'SELiberiaFiles/population.txt',
           'roadFile':'SELiberiaFiles/network.txt',
           'exclusionFile':'SELiberiaFiles/candidates.txt',
           'useDB':'EbolaMonroviaFull',
           'filterAccessible':False,
           'trimRadius':20,
           'sparsifyX':False,
           'sparsifyY':False,
           'sparsifyLimit':1,
           'distMethod':'reverse'}

cfg['extras'] = {'permanent':[]}

cfg['pickledRun'] = False
cfg['pickledDist'] = False
#cfg['resourceFile']='SELiberiaFiles/hospitals.txt',


#Travel modes = crow or path
#Population modes = density or discrete
#Obstacles = odds of obstructed point on network map

# %%
fromFile = False

def importFile(ref,mapper = 'null',limit='null'):
    paramDict = dict()
    fileIn = open(ref)
    content = [line.replace('\n','').replace('\t',' ').replace('\r','').replace('  ',' ') for line in fileIn.readlines()]
    fileIn.close()
    dLen = max([len(line) for line in content])
    params = [entry for entry in content if len(entry) < (.5*dLen)]
    entries = [entry.split(' ') for entry in content if len(entry) >= (.5*dLen)]
    entries = [[entry for entry in row if entry != ''] for row in entries]
    for i in range(len(params)):
        entry = params[i].replace('\t',' ')
        while '  ' in entry:
            entry = entry.replace('  ', ' ')
        temp = entry.split(' ')
        try:
            paramDict[temp[0]] = float(temp[1])
        except:
            try:
                paramDict[temp[0]] = temp[1]
            except:
                None
    xLen = len(entries)
    yLen = len(entries[0])
    print 'x:',xLen,'y:',yLen
    print paramDict
    if mapper != 'null':
        try:
            entries = [[mapper[entry] for entry in row] for row in reversed(entries)]
        except:
            entries = [[mapper[float(entry)] for entry in row] for row in reversed(entries)]
    else:
        entries = [[float(entry) for entry in row] for row in reversed(entries)]
    if limit != 'null':
        for x in range(xLen):
            for y in range(yLen):
                if entries[x][y]<limit:
                    entries[x][y] = 0
    return entries


if cfg['resourceFile'] != False or cfg['populationFile'] != False or cfg['roadFile'] != False:
    fromFile = True
    roadMapper = {-9999.0:-1,1:0.03333} #60mph hwy, 20mph local, 2mph offroad
    roads = importFile(cfg['roadFile'],mapper=roadMapper)
    population = importFile(cfg['populationFile'],limit=2)
    cfg['extras']['exclude'] = importFile(cfg['exclusionFile'])
    resourceList = []
    if cfg['resourceFile'] != False:
        resources = importFile(cfg['resourceFile'])
        for x in range(xSize):
            for y in range(ySize):
                if resources[x][y] != 0:
                    resourceList.append([x,y])
    print "Number of resources:",len(resourceList)
    cfg['xSize'] = xSize = len(population)
    cfg['ySize'] = ySize = len(population[0])
    
print "From file:", fromFile
#for pos in range(10):
#    print pos, len(extract(population,pos,99999))
# Out:
# x: 259 y: 284
# {'ncols': 284.0, 'cellsize': 0.00833333333333, 'nrows': 259.0, 'xllcorner': -9.741109753912, 'yllcorner': 4.350000000048, 'NODATA_value': -9999.0}
# x: 176 y: 284
# {'14': 13.0, 'ncols': 284.0, '-9999': -9999.0, 'cellsize': 0.0083333333333299, 'nrows': 259.0, '3': 7.0, '4': 10.0, 'xllcorner': -9.741109753912, 'yllcorner': 4.350000000048, 'NODATA_value': -9999.0}
# x:
#  259 y: 284
# {'ncols': 284.0, 'cellsize': 0.0083333333333299, 'nrows': 259.0, 'xllcorner': -9.741109753912, 'yllcorner': 4.350000000048, 'NODATA_value': -9999.0}
# Number of resources: 0
# From file: True

# %% [markdown]
# ### Population, Obstacle, and Resource Location Generation

# %%
#Randomly places lake obstacles if network mode is used
cfg['extras']['permanent'] = []

if cfg['travel'] == 'network' and not fromFile:
    lakes = zeros((size,size)); fill = cfg['landFill']
    lakes.fill(fill)
    if not fromPickle:
        for x in range(size/lakeSize):
            for y in range(size/lakeSize):
                if random() < pLake:
                    for i in range(lakeSize):
                        for j in range(lakeSize):
                            lakes[x*lakeSize+i][y*lakeSize+j] = -1
        pLocs = []
        for pt in range(nPopulation):
            x,y = randint(0,size-1),randint(0,size-1)
            while lakes[x][y] != cfg['landFill']:
                x,y = randint(0,size-1),randint(0,size-1)
            pLocs.append([x,y])
        cfg['extras']['lakes'] = lakes
    else:
        cfg['extras']['lakes'] = runP['map']
        pLocs = runP['towns']
    if cfg['permanent'] != 0:
        perm = []
        for pt in range(cfg['permanent']):
            x,y = randint(0,size-1),randint(0,size-1)
            while cfg['extras']['lakes'][x][y] != cfg['landFill']:
                x,y = randint(0,size-1),randint(0,size-1)
            perm.append([x,y])
        cfg['extras']['permanent'] = perm
elif not fromFile:
    pLocs = [[randint(0,size-1),randint(0,size-1)] for x in range(nPopulation)]
    if cfg['permanent'] != 0:
        cfg['extras']['permanent']= [[randint(0,size-1),randint(0,size-1)] for x in range(cfg['permanent'])]


#Extract pts from matrix
def extract(matrix,minV,maxV):
    listed = []
    for x in range(len(matrix)):
        for y in range(len(matrix[0])):
            if matrix[x][y]>minV and matrix[x][y]<maxV:
                listed.append([x,y])
    return listed        
        

#If population stored by density, creates density matrix
if cfg['population'] == 'density' and not fromFile:
    cfg['extras']['occupied'] = pLocs
    temp = zeros((size,size))
    for i in range(nPopulation):
        temp[pLocs[i][0]][pLocs[i][1]] += random()
    pLocs = temp
elif not fromFile:
    cfg['extras']['occupied'] = pLocs
            

#Extracting point lists from matrices   
if cfg['travel'] == 'network' and fromFile:
    cfg['extras']['lakes'] = roads
    pLocs = population
    cfg['extras']['occupied'] = extract(pLocs,0,9999999999999999)
    if cfg['resourceFile'] != False:
        cfg['extras']['permanent'] = extract(resources,0,999) 
    

#Calculating neighbors if hill climber constrained to populated points    
if cfg['inCityH']:
    neighbors = []
    for i in range(nPopulation):
        d = cfg['wander'] + 1
        x = cfg['extras']['occupied'][i][0]
        y = cfg['extras']['occupied'][i][1]
        accessible = [loc for loc in cfg['extras']['occupied'] if loc[0]<(x+d) and loc[0]>(x-d) and loc[1]<(y+d) and loc[1]>(y-d)]
        accessible = [loc for loc in accessible if cfg['extras']['exclude'][loc[0]][loc[1]] == 1]
        neighbors.append(deepcopy(accessible))
        
    cfg['extras']['neighbors'] = neighbors
    
if cfg['inCityD']:
    cfg['extras']['postExclusion'] = [loc for loc in cfg['extras']['occupied'] if cfg['extras']['exclude'][loc[0]][loc[1]] == 1]
    
if cfg['resourceFile'] != False:
    print "Fixed resources:",extract(resources,0,999)
else:
    print "No fixed resources found"
# Out:
# No fixed resources found

# %%
#Removing inaccessible locations
if cfg['filterAccessible']:
    print "Population filtered by road accessibility"
    cfg['extras']['occupied'] = [i for i in cfg['extras']['occupied'] if cfg['extras']['lakes'][i[0]][i[1]] != -1]
#Add low speed roads to occupied pts
else:
    print "Speed 1 road network added to populated areas"
    for i in cfg['extras']['occupied']:
        if cfg['extras']['lakes'][i[0]][i[1]] == -1:
            cfg['extras']['lakes'][i[0]][i[1]] = 1
# Out:
# Speed 1 road network added to populated areas

# %%
#Scatters initial set of resources
rLocs = [[randint(0,cfg['xSize']-1),randint(0,cfg['ySize']-1)] for x in range(nResource)]

# %% [markdown]
# ### Network Population Function for Manhattan Distance Travel

# %%
def getNetwork(cfg,size):
    """Generates Network for Manhattan Distance Travel"""
    network=nx.Graph()
    try:
        xSize = cfg['xSize']
    except:
        xSize = size
    try:
        ySize = cfg['ySize']
    except:
        ySize = size

    for x in range(xSize-1):
        for y in range(ySize):
            if cfg['extras']['lakes'][x+1][y] != -1 and cfg['extras']['lakes'][x][y] != -1:
                weight = max([cfg['extras']['lakes'][x+1][y],cfg['extras']['lakes'][x][y]])
                network.add_edge(str([x+1,y]),str([x,y]),weight = weight)
    for x in range(xSize):
        for y in range(ySize-1):
            if cfg['extras']['lakes'][x][y+1] != -1 and cfg['extras']['lakes'][x][y] != -1:
                weight = max([cfg['extras']['lakes'][x][y+1],cfg['extras']['lakes'][x][y]])
                network.add_edge(str([x,y+1]),str([x,y]),weight = weight)
                
    if cfg['roads'] >= 0: 
        roadV = cfg['roadLimit']
        for x in range(xSize-1):
            for y in range(ySize-1):
                if cfg['extras']['lakes'][x][y] != -1 and cfg['extras']['lakes'][x+1][y+1] != -1:
                    if cfg['extras']['lakes'][x][y] < roadV and cfg['extras']['lakes'][x+1][y+1] < roadV:
                        weight = max([cfg['extras']['lakes'][x][y],cfg['extras']['lakes'][x+1][y+1]])
                        network.add_edge(str([x,y]),str([x+1,y+1]),weight = weight*1.41421356237)
        for x in range(1,xSize):
            for y in range(ySize-1):
                if cfg['extras']['lakes'][x][y] != -1 and cfg['extras']['lakes'][x-1][y+1] != -1: 
                    if cfg['extras']['lakes'][x][y] < roadV and cfg['extras']['lakes'][x-1][y+1] < roadV:
                        weight = max([cfg['extras']['lakes'][x][y],cfg['extras']['lakes'][x-1][y+1]])
                        network.add_edge(str([x,y]),str([x-1,y+1]),weight = weight*1.41421356237)
                
    return network


cfg['extras']['network'] = getNetwork(cfg,0)
#nx.draw(cfg['extras']['network'])

# %% [markdown]
# ### Sparsify function reduces resolution for nodes below a reachability threshold for high resolution runs

# %%
def sparsify(network,cfg,pLocs,size,rLocs):
    limit = cfg['sparsifyLimit']
    newNet = deepcopy(network)
    try:
        xSize = cfg['xSize']
    except:
        xSize = size
    try:
        ySize = cfg['ySize']
    except:
        ySize = size

    destinations = rLocs + cfg['extras']['permanent']
    if cfg['sparsifyX']:
        for x in range(0,xSize-1,2):
            for y in range(ySize):
                if cfg['extras']['lakes'][x][y]>=limit and cfg['extras']['lakes'][x+1][y]>=limit and [x+1,y] not in destinations:
                    try:
                        newNet.remove_node(str([x+1,y]))
                        cfg['extras']['lakes'][x+1][y] = -1
                        pLocs[x][y] += pLocs[x+1][y]
                        pLocs[x+1][y] = 0
                        #print "removing x node",x,y
                    except:
                        None
                    try:
                        #print "adding x edge",x,y,x+2,y
                        weight = max(cfg['extras']['lakes'][x][y],cfg['extras']['lakes'][x+2][y])
                        newNet.add_edge(str([x,y]),str([x+2,y]),weight = 2*weight)
                    except:
                        None
        print "X Sparsification complete"
    if cfg['sparsifyY']:
        for x in range(xSize):
            for y in range(0,ySize-1,2):
                if cfg['extras']['lakes'][x][y]>=limit and cfg['extras']['lakes'][x][y+1]>=limit and [x,y+1] not in destinations:
                    try:
                        newNet.remove_node(str([x,y+1]))
                        cfg['extras']['lakes'][x][y+1] = -1
                        pLocs[x][y] += pLocs[x][y+1]
                        pLocs[x][y+1] = 0
                        #print "removing y node",x,y
                    except:
                        None
                    try:
                        #print "adding y edge",x,y,x,y+2
                        weight = max(cfg['extras']['lakes'][x][y],cfg['extras']['lakes'][x][y+2])
                        newNet.add_edge(str([x,y]),str([x,y+2]),weight = 2*weight)
                    except:
                        None
        print "Y Sparsification complete"
    occupied = extract(pLocs,0,99999)
    return newNet,pLocs,occupied,cfg['extras']['lakes']
            
if cfg['sparsifyY'] or cfg['sparsifyY']:      
    cfg['extras']['network'],pLocs,cfg['extras']['occupied'],cfg['extras']['lakes'] = sparsify(netTemp,cfg,pLocs,0,rLocs)

# %%
def getKey(key1,key2):
	pt1 = key1
	pt2 = listFromStr(key2)
	return str(rank(pt1[0],pt1[1],pt2[0],pt2[1]))

def listFromStr(text):
    return [int(entry) for entry in list(text.replace('[','').replace(']','').replace('(','').replace(')','').split(','))]

# %% [markdown]
# ### Prioritizes Points to Reduce Redundancy

# %%
def rank(x1,y1,x2,y2):
    if x1 < x2:
        return x1,y1,x2,y2
    elif x1 > x2:
        return x2,y2,x1,y1
    elif y1 < y2:
        return x1,y1,x2,y2
    else:
        return x2,y2,x1,y1

# %% [markdown]
# ### Reverse Lookup Method, find all distances to a give resource location

# %%
def reverseLookup(cfg,rLocs,pLocs):
    try:
        last = cfg['extras']['last']
    except:
        last = dict()
    distances = dict()
    data = []
    weights = []
    destinations = rLocs+cfg['extras']['permanent']
    destStrings = []
    for pt in destinations:
        key = str(pt)
        try:
            distances[key] = last[key]
            destStrings.append(key)
        except:
            try:
                distances[key] = nx.single_source_dijkstra_path_length(cfg['extras']['network'],key)
                destStrings.append(key)
            except:
                None
                #print pt, "appears to be solitary"
    for pt in cfg['extras']['occupied']:
        trips = set()
        key = str(pt)
        for dest in destStrings:
            try:
                trips.add(distances[dest][key])
            except:
                None
        if len(trips) != 0:
            data.append(min(trips))
            weights.append(pLocs[pt[0]][pt[1]])
    cfg['extras']['last'] = destinations
    #print average(data)
    #print distances.items()[0]
    return data, weights

# %% [markdown]
# ### Worker Functions

# %%
def getPts(locs):
    """Converts pt list to plotable format"""
    ptsX = [pt[0] for pt in locs]
    ptsY = [pt[1] for pt in locs]
    return ptsX,ptsY

# %%
def getStats(pLocs,rLocs,cfg):
    """Return distance stats"""
    if cfg['threads'] != 1:
        mgr = Manager(); cfgP = mgr.dict(cfg)
        out_q = Queue()
        
        block = int(ceil(len(cfg['extras']['occupied'])/float(cfg['threads'])))
        processes = []; distances = []

        for i in range(cfg['threads']):
            p = Process(target = statsProc, args = (pLocs,rLocs,cfgP,i,cfg['extras']['occupied'][block*i:block*(i+1)],out_q))
            processes.append(p)
            p.start()
            merged = {}
        for i in range(cfg['threads']):
            merged.update(out_q.get())
        for p in processes:
            p.join()
        for i in range(cfg['threads']):
            distances += merged[i]
        cfg = dict(cfgP.items())
            
    else:
        if cfg['distMethod'] != 'reverse':
            distances = [getClosest(pt,rLocs,cfg) for pt in cfg['extras']['occupied']]
        else:
            distances,weights = reverseLookup(cfg,rLocs,pLocs)
        
    if cfg['population'] == 'discrete':
        return {'max':max(distances),
                'min':min(distances),
                'mean':mean(distances),
                'std':std(distances)}
    else:
        if cfg['distMethod'] != 'reverse':
            weights = [pLocs[pt[0]][pt[1]] for pt in cfg['extras']['occupied']]
        mean = average(distances, weights=weights)
        return {'max':max(distances),
                'min':min(distances),
                'mean':mean,
                'std':pow(average((distances-mean)**2, weights=weights),0.5)}

# %% [markdown]
# ### Plot Generation

# %%
def mapTransparency(grid,coloredGrid):
    temp = deepcopy(coloredGrid)
    maxVal = max([max(row) for row in grid])
    for i in range(len(temp)):
        for j in range(len(temp[0])):
            
            temp[i][j][3] = pow((float(grid[i][j])/maxVal),.30)
    return temp


def mapColors(grid,level,cmap):
    cNorm = colors.Normalize(vmin=0, vmax=level)
    scalarMap = cm.ScalarMappable(norm=cNorm, cmap=cmap)
    if type(grid) is list:
        temp = array(grid).tolist()
    else:
        temp = grid.tolist()
    for x in range(len(grid)):
        for y in range(len(grid[0])):
            temp[x][y] = list(scalarMap.to_rgba(float(grid[x][y])))
    return temp


def pltLocs(pLocs,rLocs,cfg,stats='null',
            title='null',
            call='null',
            cmap ='autumn_r', 
            cmap2 = 'spring',
            transpose = True,
            popAlpha = 1):
    if call == 'animate':
        plt.clf()
    else:
        fig = plt.figure(figsize=(figSize,figSize))
    
    
    if cfg['travel'] == 'network':
        plt.imshow(cfg['extras']['lakes'],cmap=cmap,interpolation='nearest',alpha =0.7)
        plt.xlim(0,len(cfg['extras']['lakes'][0]))
        plt.ylim(0,len(cfg['extras']['lakes']))
    else:
        plt.xlim(0,max([entry[0] for entry in cfg['extra']['occupied']]))
        plt.ylim(0,max([entry[1] for entry in cfg['extra']['occupied']]))
    if cfg['population'] == 'discrete':
        pX,pY = getPts(pLocs)
        plt.scatter(pY,pX, s=2, c='black', alpha=0.25)
    else:
        colorized = mapColors(pLocs,1,cmap2)
        colorized = mapTransparency(pLocs,colorized)
        plt.imshow(colorized,cmap=cmap2,interpolation='nearest',zorder=2,alpha = popAlpha)
    rX,rY = getPts(rLocs)
    plt.scatter(rY,rX, s=150, c='red', alpha=1, zorder=3)
    bX,bY = getPts(cfg['extras']['permanent'])
    plt.scatter(bY,bX, s=150, c='blue', alpha=1, zorder=3)
    cfg['extras']['permanent']
    if title != 'null':
        plt.title(title)
    if stats != 'null':
        plt.xlabel('Mean Travel Time %s\nMax Travel Time: %s\nStd Dev: %s' % (stats['mean'],stats['max'],stats['std']))
    if call != 'animate':
        plt.show()
    return plt

# %% [markdown]
# ### Starting Conditions

# %%
pltLocs(pLocs,rLocs,cfg,cmap='Greys_r',cmap2='autumn_r', transpose = True, popAlpha = 1)
# Out:
# <module 'matplotlib.pyplot' from '/Library/Python/2.7/site-packages/matplotlib/pyplot.pyc'>

# %% [markdown]
# ### Denaturing Algorithm

# %%
def denature(pLocs,rLocs,meanTilt,cfg,
             tracker=[],
             stopLimit = 50,
             timeLimit = 20000,
             showEvery = 25,
             best = 10000000,
             bestStats=dict()):
    
    """Randomly replaces 1 to n/2 resource locations and keeps if new solution scores better"""
    n = len(rLocs)
    gen = 0
    scores = []
    bestStats = dict()
    t1 = datetime.datetime.now()
    while len(scores)<stopLimit or len(set(scores[-stopLimit:])) != 1:
        newLocs = deepcopy(rLocs)
        ids = sample(range(n),randint(1,int(n/2.+.5)))
        for x in ids:
            if cfg['inCityD']:
                loc = choice(cfg['extras']['postExclusion'])
            else:
                loc = [randint(0,cfg['xSize']-1),randint(0,cfg['ySize']-1)]
            newLocs[x] = loc
        stats = getStats(pLocs,newLocs,cfg)
        score = stats['mean']*meanTilt + stats['max']*(1-meanTilt)
        if best > score:
            rLocs = deepcopy(newLocs); bestStats = deepcopy(stats)
            best = score
            tracker.append({'gen':'Denature %s' % gen,'score':score,'stats':deepcopy(stats),'pts':deepcopy(rLocs)})
        if gen%showEvery == 0:
            print "Best: %s   Uni: %s   Gen: %s   Mean: %s   Max: %s   Std: %s   Time: %s" % (best,
                                                                   len(set(scores[-stopLimit:])),
                                                                   gen,bestStats['mean'],
                                                                   bestStats['max'],
                                                                   bestStats['std'],
                                                                   (datetime.datetime.now()-t1).seconds)
        if gen%(showEvery*20) == 0:
            pltLocs(pLocs,rLocs,cfg,bestStats,title='Denaturer Gen %s Optimal Placement' % gen,cmap='Greys_r',cmap2='autumn_r')
        if gen == timeLimit:
            break
        scores.append(best)
        gen += 1
    if gen == timeLimit:
        print "\nGeneration limit reached after %s generations" % timeLimit
    else:
        print "\nStable solution found at generation %s and maintained for %s generations" % (gen-stopLimit,stopLimit)
    pltLocs(pLocs,rLocs,cfg,bestStats,title='Gen %s Optimal Placement' % gen,cmap='Greys_r',cmap2='autumn_r')
    print len(tracker), "improvements made"
    return rLocs,tracker,best,bestStats

# %% [markdown]
# ### Hill Climber Algorithm

# %%
def climb(pLocs,rLocs,meanTilt,cfg,
             tracker=[],
             stopLimit = 50,
             timeLimit = 20000,
             showEvery = 25,
             best = 10000000,
             bestStats=dict()):
    """Randomly nudges 1 to n/2 resources locations and keeps if new solution is better"""
    n = len(rLocs)
    gen = 0
    scores = []
    t1 = datetime.datetime.now()
    while len(scores)<stopLimit or len(set(scores[-stopLimit:])) != 1:
        newLocs = deepcopy(rLocs)
        ids = sample(range(n),randint(1,int(n/2.+.5)))
        for x in ids:
            if cfg['inCityH']:
                loc = choice(cfg['extras']['neighbors'][x])
            else:
                loc = [rLocs[x][0]+randint(-cfg['wander'],cfg['wander']),rLocs[x][1]+randint(-cfg['wander'],cfg['wander'])]
            newLocs[x] = loc
        stats = getStats(pLocs,newLocs,cfg)
        score = stats['mean']*meanTilt + stats['max']*(1-meanTilt)
        if best > score:
            rLocs = deepcopy(newLocs); bestStats = deepcopy(stats)
            best = score
            tracker.append({'gen':'Hill Climber %s' % gen,'score':score,'stats':deepcopy(stats),'pts':deepcopy(rLocs)})
        if gen%showEvery == 0:
            print "Best: %s   Uni: %s   Gen: %s   Mean: %s   Max: %s   Std: %s   Time: %s" % (best,
                                                                   len(set(scores[-stopLimit:])),
                                                                   gen,bestStats['mean'],
                                                                   bestStats['max'],
                                                                   bestStats['std'],
                                                                   (datetime.datetime.now()-t1).seconds)
        if gen%(showEvery*20) == 0:
            pltLocs(pLocs,rLocs,cfg,bestStats,title='Hill Climber Gen %s Optimal Placement' % gen,cmap='Greys_r',cmap2='autumn_r')
        if gen == timeLimit:
            break
        scores.append(best)
        gen += 1
    if gen == timeLimit:
        print "\nGeneration limit reached after %s generations" % timeLimit
    else:
        print "\nStable solution found at generation %s and maintained for %s generations" % (gen-stopLimit,stopLimit)
    pltLocs(pLocs,rLocs,cfg,bestStats,title='Gen %s Optimal Placement' % gen,cmap='Greys_r',cmap2='autumn_r')
    print len(tracker), "improvements made"    
    return rLocs,tracker,best,bestStats

# %% [markdown]
# ### Experiment Results

# %%
#Denature until stable solution is maintained for 30000 generations
stagnantLimit = 2000
best = 10000000
showEvery = 50
cfg['threads'] = 1

rLocs,tracker,best,bestStats = denature(pLocs,rLocs,meanTilt,cfg,
                              stopLimit = stagnantLimit,
                              timeLimit = 'null',
                              showEvery = showEvery,
                              best = best)
# Out:
# Best: 9.34332677513   Uni: 0   Gen: 0   Mean: 3.24603838148   Max: 33.7324803497   Std: 3.47275560732   Time: 1
# Best: 8.37411042395   Uni: 8   Gen: 50   Mean: 2.86932417423   Max: 30.3932554228   Std: 3.250009583   Time: 72
# Best: 8.37411042395   Uni: 8   Gen: 100   Mean: 2.86932417423   Max: 30.3932554228   Std: 3.250009583   Time: 129
# Best: 8.36923258421   Uni: 10   Gen: 150   Mean: 2.86322687456   Max: 30.3932554228   Std: 3.42929988896   Time: 188
# Best: 8.36232297218   Uni: 11   Gen: 200   Mean: 2.85458985952   Max: 30.3932554228   Std: 3.41096102665   Time: 249
# Best: 8.36232297218   Uni: 11   Gen: 250   Mean: 2.85458985952   Max: 30.3932554228   Std: 3.41096102665   Time: 309
# Best: 8.36232297218   Uni: 11   Gen: 300   Mean: 2.85458985952   Max: 30.3932554228   Std: 3.41096102665   Time: 371
# Best: 8.36232297218   Uni: 11   Gen: 350   Mean: 2.85458985952   Max: 30.3932554228   Std: 3.41096102665   Time: 430
# Best: 8.3459461394   Uni: 12   Gen: 400   Mean: 2.83411881855   Max: 30.3932554228   Std: 3.37981658393   Time: 490
# Best: 8.31847169047   Uni: 14   Gen: 450   Mean: 2.79977575739   Max: 30.3932554228   Std: 3.27246922208   Time: 549
# Best: 8.31847169047   Uni: 14   Gen: 500   Mean: 2.79977575739   Max: 30.3932554228   Std: 3.27246922208   Time: 608
# Best: 8.31634827165   Uni: 15   Gen: 550   Mean: 2.79712148386   Max: 30.3932554228   Std: 3.2708322093   Time: 667
# Best: 8.31634827165   Uni: 15   Gen: 600   Mean: 2.79712148386   Max: 30.3932554228   Std: 3.2708322093   Time: 727
# Best: 8.31392269281   Uni: 17   Gen: 650   Mean: 2.79408951031   Max: 30.3932554228   Std: 3.13704942187   Time: 786
# Best: 8.31392269281   Uni: 17   Gen: 700   Mean: 2.79408951031   Max: 30.3932554228   Std: 3.13704942187   Time: 847
# Best: 8.31392269281   Uni: 17   Gen: 750   Mean: 2.79408951031   Max: 30.3932554228   Std: 3.13704942187   Time: 906
# Best: 8.27626745349   Uni: 18   Gen: 800   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 965
# Best: 8.27626745349   Uni: 18   Gen: 850   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1025
# Best: 8.27626745349   Uni: 18   Gen: 900   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1085
# Best: 8.27626745349   Uni: 18   Gen: 950   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1144
# Best: 8.27626745349   Uni: 18   Gen: 1000   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1210
# Best: 8.27626745349   Uni: 18   Gen: 1050   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1292
# Best: 8.27626745349   Uni: 18   Gen: 1100   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1357
# Best: 8.27626745349   Uni: 18   Gen: 1150   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1423
# Best: 8.27626745349   Uni: 18   Gen: 1200   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1489
# Best: 8.27626745349   Uni: 18   Gen: 1250   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1554
# Best: 8.27626745349   Uni: 18   Gen: 1300   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1620
# Best: 8.27626745349   Uni: 18   Gen: 1350   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1687
# Best: 8.27626745349   Uni: 18   Gen: 1400   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1752
# Best: 8.27626745349   Uni: 18   Gen: 1450   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1820
# Best: 8.27626745349   Uni: 18   Gen: 1500   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1886
# Best: 8.27626745349   Uni: 18   Gen: 1550   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1953
# Best: 8.27626745349   Uni: 18   Gen: 1600   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2021
# Best: 8.27626745349   Uni: 18   Gen: 1650   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2088
# Best: 8.27626745349   Uni: 18   Gen: 1700   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2156
# Best: 8.27626745349   Uni: 18   Gen: 1750   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2238
# Best: 8.27626745349   Uni: 18   Gen: 1800   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2319
# Best: 8.27626745349   Uni: 18   Gen: 1850   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2398
# Best: 8.27626745349   Uni: 18   Gen: 1900   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2479
# Best: 8.27626745349   Uni: 18   Gen: 1950   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2557
# Best: 8.27626745349   Uni: 18   Gen: 2000   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2632
# Best: 8.27626745349   Uni: 11   Gen: 2050   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2725
# Best: 8.27626745349   Uni: 11   Gen: 2100   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2803
# Best: 8.27626745349   Uni: 9   Gen: 2150   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2876
# Best: 8.27626745349   Uni: 8   Gen: 2200   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 2946
# Best: 8.27626745349   Uni: 8   Gen: 2250   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 3014
# Best: 8.27626745349   Uni: 8   Gen: 2300   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 3078
# Best: 8.27626745349   Uni: 8   Gen: 2350   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 3142
# Best: 8.27626745349   Uni: 7   Gen: 2400   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 3206
# Best: 8.27626745349   Uni: 5   Gen: 2450   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 3270
# Best: 8.27626745349   Uni: 5   Gen: 2500   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 3334
# Best: 8.27626745349   Uni: 4   Gen: 2550   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 3399
# Best: 8.27626745349   Uni: 4   Gen: 2600   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 3463
# Best: 8.27626745349   Uni: 2   Gen: 2650   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 3527
# Best: 8.27626745349   Uni: 2   Gen: 2700   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 3591
# Best: 8.27626745349   Uni: 2   Gen: 2750   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 3656
# Stable solution found at generation 791 and maintained for 2000 generations
# 18 improvements made

# %%
#Hill climb until stable solution is maintained for 3000 generations
cfg['threads'] = 1
stagnantLimit = 4000

rLocs,tracker,best,bestStats = climb(pLocs,rLocs,meanTilt,cfg,
                              stopLimit = stagnantLimit,
                              timeLimit = 'null',
                              showEvery = showEvery,
                              best = best,
                              bestStats = bestStats,
                              tracker = tracker)
# Out:
# Best: 8.27626745349   Uni: 0   Gen: 0   Mean: 2.74702046115   Max: 30.3932554228   Std: 3.12966961768   Time: 1
# Best: 8.27123204912   Uni: 3   Gen: 50   Mean: 2.7407262057   Max: 30.3932554228   Std: 3.13303040786   Time: 75
# Best: 8.21749240751   Uni: 9   Gen: 100   Mean: 2.74568489172   Max: 30.1047224707   Std: 3.11643370265   Time: 136
# Best: 8.21599666695   Uni: 10   Gen: 150   Mean: 2.74381521602   Max: 30.1047224707   Std: 3.11064481298   Time: 197
# Best: 8.20938876442   Uni: 12   Gen: 200   Mean: 2.75567177236   Max: 30.0242567326   Std: 3.1074771949   Time: 260
# Best: 8.20858591953   Uni: 14   Gen: 250   Mean: 2.75466821625   Max: 30.0242567326   Std: 3.10791216518   Time: 322
# Best: 8.18657593067   Uni: 17   Gen: 300   Mean: 2.7541750337   Max: 29.9161795185   Std: 3.11017085947   Time: 383
# Best: 8.16843730049   Uni: 19   Gen: 350   Mean: 2.75506961499   Max: 29.8219080425   Std: 3.11363828887   Time: 445
# Best: 8.1564635678   Uni: 23   Gen: 400   Mean: 2.74010244913   Max: 29.8219080425   Std: 3.12676196872   Time: 506
# Best: 8.13274735774   Uni: 25   Gen: 450   Mean: 2.73890612107   Max: 29.7081123044   Std: 3.13103583239   Time: 566
# Best: 8.13042132311   Uni: 26   Gen: 500   Mean: 2.73599857777   Max: 29.7081123044   Std: 3.14041146659   Time: 629
# Best: 8.12767979673   Uni: 28   Gen: 550   Mean: 2.7409041698   Max: 29.6747823044   Std: 3.14729940029   Time: 692
# Best: 8.12767979673   Uni: 28   Gen: 600   Mean: 2.7409041698   Max: 29.6747823044   Std: 3.14729940029   Time: 753
# Best: 8.11328499151   Uni: 29   Gen: 650   Mean: 2.75135959779   Max: 29.5609865664   Std: 3.14090304071   Time: 814
# Best: 8.11097749722   Uni: 31   Gen: 700   Mean: 2.74847522992   Max: 29.5609865664   Std: 3.1619941847   Time: 874
# Best: 8.0922155506   Uni: 33   Gen: 750   Mean: 2.76525566566   Max: 29.4000550903   Std: 3.14852785066   Time: 933
# Best: 8.0922155506   Uni: 33   Gen: 800   Mean: 2.76525566566   Max: 29.4000550903   Std: 3.14852785066   Time: 990
# Best: 8.09162238636   Uni: 34   Gen: 850   Mean: 2.76451421036   Max: 29.4000550903   Std: 3.15175354923   Time: 1048
# Best: 8.09119924051   Uni: 35   Gen: 900   Mean: 2.76398527805   Max: 29.4000550903   Std: 3.15838211004   Time: 1105
# Best: 8.08883119731   Uni: 38   Gen: 950   Mean: 2.76102522405   Max: 29.4000550903   Std: 3.15835614735   Time: 1164
# Best: 8.08703650084   Uni: 39   Gen: 1000   Mean: 2.76223328798   Max: 29.3862493523   Std: 3.15770425503   Time: 1222
# Best: 8.07212349416   Uni: 40   Gen: 1050   Mean: 2.77204096414   Max: 29.2724536143   Std: 3.15255115829   Time: 1295
# Best: 8.07167549168   Uni: 41   Gen: 1100   Mean: 2.77148096104   Max: 29.2724536143   Std: 3.16621836211   Time: 1355
# Best: 8.07159643104   Uni: 42   Gen: 1150   Mean: 2.77138213523   Max: 29.2724536143   Std: 3.15729363101   Time: 1412
# Best: 8.06999291055   Uni: 43   Gen: 1200   Mean: 2.76937773463   Max: 29.2724536143   Std: 3.15788107962   Time: 1470
# Best: 8.06999291055   Uni: 43   Gen: 1250   Mean: 2.76937773463   Max: 29.2724536143   Std: 3.15788107962   Time: 1527
# Best: 8.06978943347   Uni: 44   Gen: 1300   Mean: 2.76912338827   Max: 29.2724536143   Std: 3.16413052949   Time: 1583
# Best: 8.05112144506   Uni: 48   Gen: 1350   Mean: 2.78256983726   Max: 29.1253278762   Std: 3.15966019096   Time: 1643
# Best: 8.01495191669   Uni: 51   Gen: 1400   Mean: 2.79770723033   Max: 28.8839306621   Std: 3.13915398058   Time: 1704
# Best: 8.00307863357   Uni: 52   Gen: 1450   Mean: 2.80298206093   Max: 28.8034649241   Std: 3.13550232992   Time: 1765
# Best: 7.99529193606   Uni: 53   Gen: 1500   Mean: 2.80503262356   Max: 28.7563291861   Std: 3.12350595161   Time: 1826
# Best: 7.99089119537   Uni: 56   Gen: 1550   Mean: 2.7995316977   Max: 28.7563291861   Std: 3.11919098561   Time: 1887
# Best: 7.99089119537   Uni: 56   Gen: 1600   Mean: 2.7995316977   Max: 28.7563291861   Std: 3.11919098561   Time: 1947
# Best: 7.99089119537   Uni: 56   Gen: 1650   Mean: 2.7995316977   Max: 28.7563291861   Std: 3.11919098561   Time: 2007
# Best: 7.99046305147   Uni: 57   Gen: 1700   Mean: 2.79899651782   Max: 28.7563291861   Std: 3.11653084473   Time: 2069
# Best: 7.98838734689   Uni: 59   Gen: 1750   Mean: 2.7964018871   Max: 28.7563291861   Std: 3.12611221055   Time: 2129
# Best: 7.98838734689   Uni: 59   Gen: 1800   Mean: 2.7964018871   Max: 28.7563291861   Std: 3.12611221055   Time: 2187
# Best: 7.98435031953   Uni: 61   Gen: 1850   Mean: 2.79135560289   Max: 28.7563291861   Std: 3.12009324412   Time: 2248
# Best: 7.98312795509   Uni: 62   Gen: 1900   Mean: 2.78982764734   Max: 28.7563291861   Std: 3.11893304062   Time: 2308
# Best: 7.98312795509   Uni: 62   Gen: 1950   Mean: 2.78982764734   Max: 28.7563291861   Std: 3.11893304062   Time: 2369
# Best: 7.97062165812   Uni: 63   Gen: 2000   Mean: 2.79085977614   Max: 28.6896691861   Std: 3.11561664626   Time: 2429
# Best: 7.97062165812   Uni: 63   Gen: 2050   Mean: 2.79085977614   Max: 28.6896691861   Std: 3.11561664626   Time: 2504
# Best: 7.76722996405   Uni: 66   Gen: 2100   Mean: 2.96639676795   Max: 26.9705627484   Std: 3.21462007119   Time: 2564
# Best: 7.11357629138   Uni: 75   Gen: 2150   Mean: 2.93642197987   Max: 23.8221935374   Std: 2.9910322872   Time: 2625
# Best: 7.10726098361   Uni: 77   Gen: 2200   Mean: 2.95209571418   Max: 23.7279220613   Std: 3.00014245655   Time: 2685
# Best: 7.10646831813   Uni: 78   Gen: 2250   Mean: 2.95110488232   Max: 23.7279220613   Std: 2.98244393575   Time: 2746
# Best: 7.1047703951   Uni: 80   Gen: 2300   Mean: 2.94898247854   Max: 23.7279220613   Std: 2.98965672763   Time: 2803
# Best: 7.09805749949   Uni: 84   Gen: 2350   Mean: 2.94059135903   Max: 23.7279220613   Std: 2.97955332484   Time: 2864
# Best: 7.09805749949   Uni: 84   Gen: 2400   Mean: 2.94059135903   Max: 23.7279220613   Std: 2.97955332484   Time: 2923
# Best: 7.08758129835   Uni: 85   Gen: 2450   Mean: 2.92749610761   Max: 23.7279220613   Std: 2.94520619089   Time: 2984
# Best: 7.07707600828   Uni: 91   Gen: 2500   Mean: 2.91436449502   Max: 23.7279220613   Std: 2.92496332103   Time: 3044
# Best: 7.07707600828   Uni: 91   Gen: 2550   Mean: 2.91436449502   Max: 23.7279220613   Std: 2.92496332103   Time: 3102
# Best: 7.07684366689   Uni: 92   Gen: 2600   Mean: 2.91407406828   Max: 23.7279220613   Std: 2.9288579251   Time: 3163
# Best: 7.07684366689   Uni: 92   Gen: 2650   Mean: 2.91407406828   Max: 23.7279220613   Std: 2.9288579251   Time: 3223
# Best: 7.07684366689   Uni: 92   Gen: 2700   Mean: 2.91407406828   Max: 23.7279220613   Std: 2.9288579251   Time: 3282
# Best: 7.07684366689   Uni: 92   Gen: 2750   Mean: 2.91407406828   Max: 23.7279220613   Std: 2.9288579251   Time: 3341
# Best: 7.07684366689   Uni: 92   Gen: 2800   Mean: 2.91407406828   Max: 23.7279220613   Std: 2.9288579251   Time: 3401
# Best: 7.07684366689   Uni: 92   Gen: 2850   Mean: 2.91407406828   Max: 23.7279220613   Std: 2.9288579251   Time: 3460
# Best: 7.07684366689   Uni: 92   Gen: 2900   Mean: 2.91407406828   Max: 23.7279220613   Std: 2.9288579251   Time: 3515
# Best: 7.0763877461   Uni: 93   Gen: 2950   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 3568
# Best: 7.0763877461   Uni: 93   Gen: 3000   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 3624
# Best: 7.0763877461   Uni: 93   Gen: 3050   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 3694
# Best: 7.0763877461   Uni: 93   Gen: 3100   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 3748
# Best: 7.0763877461   Uni: 93   Gen: 3150   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 3803
# Best: 7.0763877461   Uni: 93   Gen: 3200   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 3853
# Best: 7.0763877461   Uni: 93   Gen: 3250   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 3901
# Best: 7.0763877461   Uni: 93   Gen: 3300   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 3950
# Best: 7.0763877461   Uni: 93   Gen: 3350   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 3997
# Best: 7.0763877461   Uni: 93   Gen: 3400   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 4046
# Best: 7.0763877461   Uni: 93   Gen: 3450   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 4092
# Best: 7.0763877461   Uni: 93   Gen: 3500   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 4139
# Best: 7.0763877461   Uni: 93   Gen: 3550   Mean: 2.91350416729   Max: 23.7279220613   Std: 2.93001213188   Time: 4185
# Best: 7.07620842865   Uni: 94   Gen: 3600   Mean: 2.91328002048   Max: 23.7279220613   Std: 2.93149302523   Time: 4233
# Best: 7.07620842865   Uni: 94   Gen: 3650   Mean: 2.91328002048   Max: 23.7279220613   Std: 2.93149302523   Time: 4281
# Best: 7.07620842865   Uni: 94   Gen: 3700   Mean: 2.91328002048   Max: 23.7279220613   Std: 2.93149302523   Time: 4330
# Best: 7.07620842865   Uni: 94   Gen: 3750   Mean: 2.91328002048   Max: 23.7279220613   Std: 2.93149302523   Time: 4378
# Best: 7.07620842865   Uni: 94   Gen: 3800   Mean: 2.91328002048   Max: 23.7279220613   Std: 2.93149302523   Time: 4427
# Best: 7.07620842865   Uni: 94   Gen: 3850   Mean: 2.91328002048   Max: 23.7279220613   Std: 2.93149302523   Time: 4475
# Best: 7.07620842865   Uni: 94   Gen: 3900   Mean: 2.91328002048   Max: 23.7279220613   Std: 2.93149302523   Time: 4523
# Best: 7.07584091339   Uni: 95   Gen: 3950   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 4569
# Best: 7.07584091339   Uni: 95   Gen: 4000   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 4617
# Best: 7.07584091339   Uni: 93   Gen: 4050   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 4680
# Best: 7.07584091339   Uni: 87   Gen: 4100   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 4727
# Best: 7.07584091339   Uni: 86   Gen: 4150   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 4776
# Best: 7.07584091339   Uni: 84   Gen: 4200   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 4825
# Best: 7.07584091339   Uni: 82   Gen: 4250   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 4874
# Best: 7.07584091339   Uni: 79   Gen: 4300   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 4922
# Best: 7.07584091339   Uni: 77   Gen: 4350   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 4970
# Best: 7.07584091339   Uni: 73   Gen: 4400   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5018
# Best: 7.07584091339   Uni: 71   Gen: 4450   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5066
# Best: 7.07584091339   Uni: 70   Gen: 4500   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5114
# Best: 7.07584091339   Uni: 68   Gen: 4550   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5161
# Best: 7.07584091339   Uni: 68   Gen: 4600   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5209
# Best: 7.07584091339   Uni: 67   Gen: 4650   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5257
# Best: 7.07584091339   Uni: 65   Gen: 4700   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5304
# Best: 7.07584091339   Uni: 63   Gen: 4750   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5351
# Best: 7.07584091339   Uni: 63   Gen: 4800   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5398
# Best: 7.07584091339   Uni: 62   Gen: 4850   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5444
# Best: 7.07584091339   Uni: 61   Gen: 4900   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5491
# Best: 7.07584091339   Uni: 58   Gen: 4950   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5537
# Best: 7.07584091339   Uni: 57   Gen: 5000   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5584
# Best: 7.07584091339   Uni: 56   Gen: 5050   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5643
# Best: 7.07584091339   Uni: 55   Gen: 5100   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5689
# Best: 7.07584091339   Uni: 54   Gen: 5150   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5735
# Best: 7.07584091339   Uni: 53   Gen: 5200   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5782
# Best: 7.07584091339   Uni: 53   Gen: 5250   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5830
# Best: 7.07584091339   Uni: 52   Gen: 5300   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5877
# Best: 7.07584091339   Uni: 48   Gen: 5350   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5925
# Best: 7.07584091339   Uni: 45   Gen: 5400   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 5972
# Best: 7.07584091339   Uni: 44   Gen: 5450   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6018
# Best: 7.07584091339   Uni: 43   Gen: 5500   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6066
# Best: 7.07584091339   Uni: 40   Gen: 5550   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6114
# Best: 7.07584091339   Uni: 40   Gen: 5600   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6162
# Best: 7.07584091339   Uni: 40   Gen: 5650   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6209
# Best: 7.07584091339   Uni: 39   Gen: 5700   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6257
# Best: 7.07584091339   Uni: 37   Gen: 5750   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6305
# Best: 7.07584091339   Uni: 37   Gen: 5800   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6354
# Best: 7.07584091339   Uni: 35   Gen: 5850   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6402
# Best: 7.07584091339   Uni: 34   Gen: 5900   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6449
# Best: 7.07584091339   Uni: 34   Gen: 5950   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6497
# Best: 7.07584091339   Uni: 33   Gen: 6000   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6547
# Best: 7.07584091339   Uni: 33   Gen: 6050   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6609
# Best: 7.07584091339   Uni: 30   Gen: 6100   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6657
# Best: 7.07584091339   Uni: 21   Gen: 6150   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6705
# Best: 7.07584091339   Uni: 19   Gen: 6200   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6754
# Best: 7.07584091339   Uni: 18   Gen: 6250   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6801
# Best: 7.07584091339   Uni: 16   Gen: 6300   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6849
# Best: 7.07584091339   Uni: 12   Gen: 6350   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6896
# Best: 7.07584091339   Uni: 12   Gen: 6400   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6943
# Best: 7.07584091339   Uni: 11   Gen: 6450   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 6989
# Best: 7.07584091339   Uni: 5   Gen: 6500   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7036
# Best: 7.07584091339   Uni: 5   Gen: 6550   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7084
# Best: 7.07584091339   Uni: 4   Gen: 6600   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7131
# Best: 7.07584091339   Uni: 4   Gen: 6650   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7178
# Best: 7.07584091339   Uni: 4   Gen: 6700   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7226
# Best: 7.07584091339   Uni: 4   Gen: 6750   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7273
# Best: 7.07584091339   Uni: 4   Gen: 6800   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7321
# Best: 7.07584091339   Uni: 4   Gen: 6850   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7368
# Best: 7.07584091339   Uni: 4   Gen: 6900   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7416
# Best: 7.07584091339   Uni: 3   Gen: 6950   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7463
# Best: 7.07584091339   Uni: 3   Gen: 7000   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7512
# Best: 7.07584091339   Uni: 3   Gen: 7050   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7572
# Best: 7.07584091339   Uni: 3   Gen: 7100   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7622
# Best: 7.07584091339   Uni: 3   Gen: 7150   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7669
# Best: 7.07584091339   Uni: 3   Gen: 7200   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7718
# Best: 7.07584091339   Uni: 3   Gen: 7250   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7765
# Best: 7.07584091339   Uni: 3   Gen: 7300   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7814
# Best: 7.07584091339   Uni: 3   Gen: 7350   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7861
# Best: 7.07584091339   Uni: 3   Gen: 7400   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7908
# Best: 7.07584091339   Uni: 3   Gen: 7450   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 7956
# Best: 7.07584091339   Uni: 3   Gen: 7500   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 8004
# Best: 7.07584091339   Uni: 3   Gen: 7550   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 8051
# Best: 7.07584091339   Uni: 2   Gen: 7600   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 8098
# Best: 7.07584091339   Uni: 2   Gen: 7650   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 8145
# Best: 7.07584091339   Uni: 2   Gen: 7700   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 8193
# Best: 7.07584091339   Uni: 2   Gen: 7750   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 8240
# Best: 7.07584091339   Uni: 2   Gen: 7800   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 8287
# Best: 7.07584091339   Uni: 2   Gen: 7850   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 8335
# Best: 7.07584091339   Uni: 2   Gen: 7900   Mean: 2.91282062641   Max: 23.7279220613   Std: 2.92928503841   Time: 8383
# Stable solution found at generation 3947 and maintained for 4000 generations
# 112 improvements made

# %%
def animateMaps(pLocs,tracker,cfg,cmap='gist_earth',cmap2='autumn'):
    length = len(tracker)
    fig = plt.figure(figsize=(figSize,figSize))
        
    def animate(i):
        pltLocs(pLocs,
                   tracker[i]['pts'],
                   cfg,
                   stats=tracker[i]['stats'],
                   title='Gen %s Optimal Placement' % tracker[i]['gen'],
                   call='animate',
                   cmap=cmap,
                   cmap2=cmap2)
    
    anim = animation.FuncAnimation(fig,animate,frames=length,interval=200, blit=False)
    fileName = 'mapOptimization'
    #print "Generating", fileName, "gif animation"
    #anim.save(fileName+'.gif', writer='imagemagick', fps=1)
    #sleep(3)
    print "Generating", fileName, "mp4 video"
    writer = animation.writers['ffmpeg'](fps=5)
    anim.save(fileName+'.mp4',writer=writer,dpi=250)
    return anim,fileName

# %%
anim,fileName = animateMaps(pLocs,tracker,cfg)
#display_animation(anim,fileName)
# Out:
# Generating mapOptimization mp4 video

# %% [raw]
# © 2014 James Schlitt
