# %% [markdown]
# # Resource Allocation Distance Optimizer v2

# %% [markdown]
# ### The goal of this program is to find locations for a finite set of resources such that the minimal mean distance from resource to population member is achieved without leaving any members at an excessive distance from the nearest resource.

# %%
from random import randint, sample, random, choice, uniform
from numpy import mean, std, zeros, average, array, ones, arange
from copy import deepcopy
from math import ceil, sqrt
from geopy.distance import great_circle, vincenty
from geopy import geocoders
from mpl_toolkits.axes_grid1 import make_axes_locatable

import networkx as nx
import datetime
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.ticker as ticker

import cPickle

# %matplotlib inline

# %% [markdown]
# ### Animation enabled

# %%
import matplotlib.animation as animation
from IPython.display import HTML

#Animating via tutorial at:
#http://jakevdp.github.io/blog/2013/05/12/embedding-matplotlib-animations/

VIDEO_TAG = """<video width="1024" height="768" controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def display_animation(anim,fileName):
    print "Preparing to render video in notebook..."
    plt.close(anim._fig)
    return HTML(anim_to_html(anim,fileName))

def anim_to_html(anim,fileName):
    fileName = fileName+'.mp4'
    video = open(fileName, "rb").read()
    anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

# %% [markdown]
# ### Experiment Globals

# %%
meanTilt = 0.97 #Score = tilt* mean distance + (1-tilt)* max distance
figSize = 10
nResource = 5

cfg = {'travel':'network',
           'distance':'manhattan',
           'population':'density',
           'obstacles':0.2,
           'extras':dict(),
           'precision':'int',
           'penalty':300,
           'wander':8,
           'inCityD':True,
           'inCityH':True,
           'threads':1,
           'landFill':1,
           'walkingSpeed':2,
           'roadLimit':1.1,
           'roadTimes':[0.5,0.3,0.1],
           'roads':3,
           'permanent':False,
           'pickledRun':'network.pickle',
           'pickledDist':'network.pickle',
           'resourceFile':False,
           'populationFile':'SELiberiaFiles/population.txt',
           'roadFile':'SELiberiaFiles/network.txt',
           'exclusionFile':'SELiberiaFiles/candidates.txt',
           'useDB':'EbolaMonroviaFull',
           'filterAccessible':False,
           'trimRadius':20,
           'sparsifyX':False,
           'sparsifyY':False,
           'sparsifyLimit':1,
           'distMethod':'reverse',
           'connectSolitary':True}

cfg['extras'] = {'permanent':[]}

cfg['pickledRun'] = False
cfg['pickledDist'] = False
#cfg['resourceFile']='SELiberiaFiles/hospitals.txt',


#Travel modes = crow or path
#Population modes = density or discrete
#Obstacles = odds of obstructed point on network map

# %% [markdown]
# ### Import Data From GIS Source

# %%
fromFile = False

def importFile(ref,mapper = 'null',limit='null'):
    paramDict = dict()
    fileIn = open(ref)
    content = [line.replace('\n','').replace('\t',' ').replace('\r','').replace('  ',' ') for line in fileIn.readlines()]
    fileIn.close()
    dLen = max([len(line) for line in content])
    params = [entry for entry in content if len(entry) < (.5*dLen)]
    entries = [entry.split(' ') for entry in content if len(entry) >= (.5*dLen)]
    entries = [[entry for entry in row if entry != ''] for row in entries]
    for i in range(len(params)):
        entry = params[i].replace('\t',' ')
        while '  ' in entry:
            entry = entry.replace('  ', ' ')
        temp = entry.split(' ')
        try:
            paramDict[temp[0]] = float(temp[1])
        except:
            try:
                paramDict[temp[0]] = temp[1]
            except:
                None
    xLen = len(entries)
    yLen = len(entries[0])
    print 'x:',xLen,'y:',yLen
    print paramDict
    if mapper != 'null':
        try:
            entries = [[mapper[entry] for entry in row] for row in reversed(entries)]
        except:
            entries = [[mapper[float(entry)] for entry in row] for row in reversed(entries)]
    else:
        entries = [[float(entry) for entry in row] for row in reversed(entries)]
    if limit != 'null':
        for x in range(xLen):
            for y in range(yLen):
                if entries[x][y]<limit:
                    entries[x][y] = 0
    return entries


if cfg['resourceFile'] != False or cfg['populationFile'] != False or cfg['roadFile'] != False:
    fromFile = True
    roadMapper = {-9999.0:-1,1:0.03333} #60mph hwy, 20mph local, 2mph offroad
    roads = importFile(cfg['roadFile'],mapper=roadMapper)
    population = importFile(cfg['populationFile'],limit=2)
    cfg['extras']['exclude'] = importFile(cfg['exclusionFile'])
    resourceList = []
    if cfg['resourceFile'] != False:
        resources = importFile(cfg['resourceFile'])
        for x in range(xSize):
            for y in range(ySize):
                if resources[x][y] != 0:
                    resourceList.append([x,y])
    print "Number of resources:",len(resourceList)
    cfg['xSize'] = xSize = len(population)
    cfg['ySize'] = ySize = len(population[0])
    
print "From file:", fromFile
#for pos in range(10):
#    print pos, len(extract(population,pos,99999))
# Out:
# x: 259 y: 284
# {'ncols': 284.0, 'cellsize': 0.00833333333333, 'nrows': 259.0, 'xllcorner': -9.741109753912, 'yllcorner': 4.350000000048, 'NODATA_value': -9999.0}
# x:
#  176 y: 284
# {'14': 13.0, 'ncols': 284.0, '-9999': -9999.0, 'cellsize': 0.0083333333333299, 'nrows': 259.0, '3': 7.0, '4': 10.0, 'xllcorner': -9.741109753912, 'yllcorner': 4.350000000048, 'NODATA_value': -9999.0}
# x:
#  259 y: 284
# {'ncols': 284.0, 'cellsize': 0.0083333333333299, 'nrows': 259.0, 'xllcorner': -9.741109753912, 'yllcorner': 4.350000000048, 'NODATA_value': -9999.0}
# Number of resources: 0
# From file: True

# %% [markdown]
# ### Population, Obstacle, and Resource Location Generation

# %%
#Randomly places lake obstacles if network mode is used
cfg['extras']['permanent'] = []

if cfg['travel'] == 'network' and not fromFile:
    lakes = zeros((size,size)); fill = cfg['landFill']
    lakes.fill(fill)
    if not fromPickle:
        for x in range(size/lakeSize):
            for y in range(size/lakeSize):
                if random() < pLake:
                    for i in range(lakeSize):
                        for j in range(lakeSize):
                            lakes[x*lakeSize+i][y*lakeSize+j] = -1
        pLocs = []
        for pt in range(nPopulation):
            x,y = randint(0,size-1),randint(0,size-1)
            while lakes[x][y] != cfg['landFill']:
                x,y = randint(0,size-1),randint(0,size-1)
            pLocs.append([x,y])
        cfg['extras']['lakes'] = lakes
    else:
        cfg['extras']['lakes'] = runP['map']
        pLocs = runP['towns']
    if cfg['permanent'] != 0:
        perm = []
        for pt in range(cfg['permanent']):
            x,y = randint(0,size-1),randint(0,size-1)
            while cfg['extras']['lakes'][x][y] != cfg['landFill']:
                x,y = randint(0,size-1),randint(0,size-1)
            perm.append([x,y])
        cfg['extras']['permanent'] = perm
elif not fromFile:
    pLocs = [[randint(0,size-1),randint(0,size-1)] for x in range(nPopulation)]
    if cfg['permanent'] != 0:
        cfg['extras']['permanent']= [[randint(0,size-1),randint(0,size-1)] for x in range(cfg['permanent'])]


#Extract pts from matrix
def extract(matrix,minV,maxV):
    listed = []
    for x in range(len(matrix)):
        for y in range(len(matrix[0])):
            if matrix[x][y]>minV and matrix[x][y]<maxV:
                listed.append([x,y])
    return listed        
        

#If population stored by density, creates density matrix
if cfg['population'] == 'density' and not fromFile:
    cfg['extras']['occupied'] = pLocs
    temp = zeros((size,size))
    for i in range(nPopulation):
        temp[pLocs[i][0]][pLocs[i][1]] += random()
    pLocs = temp
elif not fromFile:
    cfg['extras']['occupied'] = pLocs
            

#Extracting point lists from matrices   
if cfg['travel'] == 'network' and fromFile:
    cfg['extras']['lakes'] = roads
    pLocs = population
    cfg['extras']['occupied'] = extract(pLocs,0,9999999999999999)
    if cfg['resourceFile'] != False:
        cfg['extras']['permanent'] = extract(resources,0,999) 
    

#Calculating neighbors if hill climber constrained to populated points    
if cfg['inCityH']:
    neighbors = []
    for i in range(nPopulation):
        d = cfg['wander'] + 1
        x = cfg['extras']['occupied'][i][0]
        y = cfg['extras']['occupied'][i][1]
        accessible = [loc for loc in cfg['extras']['occupied'] if loc[0]<(x+d) and loc[0]>(x-d) and loc[1]<(y+d) and loc[1]>(y-d)]
        accessible = [loc for loc in accessible if cfg['extras']['exclude'][loc[0]][loc[1]] == 1]
        neighbors.append(deepcopy(accessible))
        
    cfg['extras']['neighbors'] = neighbors
    
if cfg['inCityD']:
    cfg['extras']['postExclusion'] = [loc for loc in cfg['extras']['occupied'] if cfg['extras']['exclude'][loc[0]][loc[1]] == 1]
    
if cfg['resourceFile'] != False:
    print "Fixed resources:",extract(resources,0,999)
else:
    print "No fixed resources found"
# Out:
# No fixed resources found

# %%
#Removing inaccessible locations
if cfg['filterAccessible']:
    print "Population filtered by road accessibility"
    cfg['extras']['occupied'] = [i for i in cfg['extras']['occupied'] if cfg['extras']['lakes'][i[0]][i[1]] != -1]
#Add low speed roads to occupied pts
else:
    print "Speed 1 road network added to populated areas"
    for i in cfg['extras']['occupied']:
        if cfg['extras']['lakes'][i[0]][i[1]] == -1:
            cfg['extras']['lakes'][i[0]][i[1]] = 1
# Out:
# Speed 1 road network added to populated areas

# %%
#Scatters initial set of resources
rLocs = [[randint(0,cfg['xSize']-1),randint(0,cfg['ySize']-1)] for x in range(nResource)]

# %% [markdown]
# ### Network Population Function for Manhattan Distance Travel

# %%
def getNetwork(cfg,size):
    """Generates Network for Manhattan Distance Travel"""
    network=nx.Graph()
    try:
        xSize = cfg['xSize']
    except:
        xSize = size
    try:
        ySize = cfg['ySize']
    except:
        ySize = size

    for x in range(xSize-1):
        for y in range(ySize):
            if cfg['extras']['lakes'][x+1][y] != -1 and cfg['extras']['lakes'][x][y] != -1:
                weight = max([cfg['extras']['lakes'][x+1][y],cfg['extras']['lakes'][x][y]])
                network.add_edge(str([x+1,y]),str([x,y]),weight = weight)
    for x in range(xSize):
        for y in range(ySize-1):
            if cfg['extras']['lakes'][x][y+1] != -1 and cfg['extras']['lakes'][x][y] != -1:
                weight = max([cfg['extras']['lakes'][x][y+1],cfg['extras']['lakes'][x][y]])
                network.add_edge(str([x,y+1]),str([x,y]),weight = weight)
                
    if cfg['roads'] >= 0: 
        roadV = cfg['roadLimit']
        for x in range(xSize-1):
            for y in range(ySize-1):
                if cfg['extras']['lakes'][x][y] != -1 and cfg['extras']['lakes'][x+1][y+1] != -1:
                    if cfg['extras']['lakes'][x][y] < roadV and cfg['extras']['lakes'][x+1][y+1] < roadV:
                        weight = max([cfg['extras']['lakes'][x][y],cfg['extras']['lakes'][x+1][y+1]])
                        network.add_edge(str([x,y]),str([x+1,y+1]),weight = weight*1.41421356237)
        for x in range(1,xSize):
            for y in range(ySize-1):
                if cfg['extras']['lakes'][x][y] != -1 and cfg['extras']['lakes'][x-1][y+1] != -1: 
                    if cfg['extras']['lakes'][x][y] < roadV and cfg['extras']['lakes'][x-1][y+1] < roadV:
                        weight = max([cfg['extras']['lakes'][x][y],cfg['extras']['lakes'][x-1][y+1]])
                        network.add_edge(str([x,y]),str([x-1,y+1]),weight = weight*1.41421356237)
                
    return network


cfg['extras']['network'] = getNetwork(cfg,0)
#nx.draw(cfg['extras']['network'])

# %% [markdown]
# ### Sparsify function reduces resolution for nodes below a reachability threshold for high resolution runs

# %%
def sparsify(network,cfg,pLocs,size,rLocs):
    limit = cfg['sparsifyLimit']
    newNet = deepcopy(network)
    try:
        xSize = cfg['xSize']
    except:
        xSize = size
    try:
        ySize = cfg['ySize']
    except:
        ySize = size

    destinations = rLocs + cfg['extras']['permanent']
    if cfg['sparsifyX']:
        for x in range(0,xSize-1,2):
            for y in range(ySize):
                if cfg['extras']['lakes'][x][y]>=limit and cfg['extras']['lakes'][x+1][y]>=limit and [x+1,y] not in destinations:
                    try:
                        newNet.remove_node(str([x+1,y]))
                        cfg['extras']['lakes'][x+1][y] = -1
                        pLocs[x][y] += pLocs[x+1][y]
                        pLocs[x+1][y] = 0
                        #print "removing x node",x,y
                    except:
                        None
                    try:
                        #print "adding x edge",x,y,x+2,y
                        weight = max(cfg['extras']['lakes'][x][y],cfg['extras']['lakes'][x+2][y])
                        newNet.add_edge(str([x,y]),str([x+2,y]),weight = 2*weight)
                    except:
                        None
        print "X Sparsification complete"
    if cfg['sparsifyY']:
        for x in range(xSize):
            for y in range(0,ySize-1,2):
                if cfg['extras']['lakes'][x][y]>=limit and cfg['extras']['lakes'][x][y+1]>=limit and [x,y+1] not in destinations:
                    try:
                        newNet.remove_node(str([x,y+1]))
                        cfg['extras']['lakes'][x][y+1] = -1
                        pLocs[x][y] += pLocs[x][y+1]
                        pLocs[x][y+1] = 0
                        #print "removing y node",x,y
                    except:
                        None
                    try:
                        #print "adding y edge",x,y,x,y+2
                        weight = max(cfg['extras']['lakes'][x][y],cfg['extras']['lakes'][x][y+2])
                        newNet.add_edge(str([x,y]),str([x,y+2]),weight = 2*weight)
                    except:
                        None
        print "Y Sparsification complete"
    occupied = extract(pLocs,0,99999)
    return newNet,pLocs,occupied,cfg['extras']['lakes']
            
if cfg['sparsifyY'] or cfg['sparsifyY']:      
    cfg['extras']['network'],pLocs,cfg['extras']['occupied'],cfg['extras']['lakes'] = sparsify(netTemp,cfg,pLocs,0,rLocs)

# %%
def getKey(key1,key2):
	pt1 = key1
	pt2 = listFromStr(key2)
	return str(rank(pt1[0],pt1[1],pt2[0],pt2[1]))

def listFromStr(text):
    return [int(entry) for entry in list(text.replace('[','').replace(']','').replace('(','').replace(')','').split(','))]

# %% [markdown]
# ### Prioritizes Points to Reduce Redundancy

# %%
def rank(x1,y1,x2,y2):
    if x1 < x2:
        return x1,y1,x2,y2
    elif x1 > x2:
        return x2,y2,x1,y1
    elif y1 < y2:
        return x1,y1,x2,y2
    else:
        return x2,y2,x1,y1

# %% [markdown]
# ### Reverse Lookup Method, find all distances to a give resource location

# %%
def reverseLookup(cfg,rLocs,pLocs):
    try:
        last = cfg['extras']['last']
    except:
        last = dict()
    distances = dict()
    data = []
    weights = []
    destinations = rLocs+cfg['extras']['permanent']
    destStrings = []
    for pt in destinations:
        key = str(pt)
        try:
            distances[key] = last[key]
            destStrings.append(key)
        except:
            try:
                distances[key] = nx.single_source_dijkstra_path_length(cfg['extras']['network'],key)
                destStrings.append(key)
            except:
                None
                #print pt, "appears to be solitary"
    for pt in cfg['extras']['occupied']:
        trips = set()
        key = str(pt)
        for dest in destStrings:
            try:
                trips.add(distances[dest][key])
            except:
                None
        if len(trips) != 0:
            data.append(min(trips))
            weights.append(pLocs[pt[0]][pt[1]])
    cfg['extras']['last'] = destinations
    #print average(data)
    #print distances.items()[0]
    return data, weights

# %% [markdown]
# ### Worker Functions

# %%
def getPts(locs):
    """Converts pt list to plotable format"""
    ptsX = [pt[0] for pt in locs]
    ptsY = [pt[1] for pt in locs]
    return ptsX,ptsY

# %%
def getStats(pLocs,rLocs,cfg):
    """Return distance stats"""
    if cfg['threads'] != 1:
        mgr = Manager(); cfgP = mgr.dict(cfg)
        out_q = Queue()
        
        block = int(ceil(len(cfg['extras']['occupied'])/float(cfg['threads'])))
        processes = []; distances = []

        for i in range(cfg['threads']):
            p = Process(target = statsProc, args = (pLocs,rLocs,cfgP,i,cfg['extras']['occupied'][block*i:block*(i+1)],out_q))
            processes.append(p)
            p.start()
            merged = {}
        for i in range(cfg['threads']):
            merged.update(out_q.get())
        for p in processes:
            p.join()
        for i in range(cfg['threads']):
            distances += merged[i]
        cfg = dict(cfgP.items())
            
    else:
        if cfg['distMethod'] != 'reverse':
            distances = [getClosest(pt,rLocs,cfg) for pt in cfg['extras']['occupied']]
        else:
            distances,weights = reverseLookup(cfg,rLocs,pLocs)
        
    if cfg['population'] == 'discrete':
        return {'max':max(distances),
                'min':min(distances),
                'mean':mean(distances),
                'std':std(distances)}
    else:
        if cfg['distMethod'] != 'reverse':
            weights = [pLocs[pt[0]][pt[1]] for pt in cfg['extras']['occupied']]
        mean = average(distances, weights=weights)
        return {'max':max(distances),
                'min':min(distances),
                'mean':mean,
                'std':pow(average((distances-mean)**2, weights=weights),0.5)}

# %% [markdown]
# ### Plot Generation

# %%
def mapTransparency(grid,coloredGrid,alphaPow):
    temp = deepcopy(coloredGrid)
    maxVal = max([max(row) for row in grid])
    for i in range(len(temp)):
        for j in range(len(temp[0])):
            
            temp[i][j][3] = pow((float(grid[i][j])/maxVal),alphaPow)
    return temp


def mapColors(grid,level,cmap):
    cNorm = colors.Normalize(vmin=0, vmax=level)
    scalarMap = cm.ScalarMappable(norm=cNorm, cmap=cmap)
    if type(grid) is list:
        temp = array(grid).tolist()
    else:
        temp = grid.tolist()
    for x in range(len(grid)):
        for y in range(len(grid[0])):
            temp[x][y] = list(scalarMap.to_rgba(float(grid[x][y])))
    return temp


def ptsToText(pts,cfg,precision = 10):
    locStrings = []
    gCoder = geocoders.GoogleV3()
    for pt in pts:
        coord = ptToCoords(pt,cfg)
        try:
            place, (lat,lon) = gCoder.geocode("%s,%s" % (coord[0],coord[1]))
        except:
            place = 'Unknown Road'
        locStrings.append('%s : {%s, %s}' % (place,str(coord[0])[0:precision],str(coord[1])[0:precision]))
    return locStrings


def pltLocs(pLocs,rLocs,cfg,stats='null',
            title='null',
            call='null',
            cmap ='Greys_r', 
            cmap2 = 'autumn_r',
            transpose = True,
            popAlpha = 1,
            alphaPow = 0.2,
            distMap = True):
    if call == 'animate' or call == 'final':
        plt.clf()
        spacer = '\n\n'
        xNudge = -.05
        yNudge = 0.87
        #fig = plt.figure(figsize=(15,15))
    else:
        fig = plt.figure(figsize=(15,15))
        spacer = ' '*7
        xNudge = -0.05
        yNudge = 1.005


    ax1 = plt.subplot(221)
    if cfg['travel'] == 'network':
        plt.imshow(cfg['extras']['lakes'],cmap=cmap,interpolation='nearest',alpha =0.7)
        plt.xlim(0,len(cfg['extras']['lakes'][0]))
        plt.ylim(0,len(cfg['extras']['lakes']))
    else:
        plt.xlim(0,max([entry[0] for entry in cfg['extra']['occupied']]))
        plt.ylim(0,max([entry[1] for entry in cfg['extra']['occupied']]))
    if cfg['population'] == 'discrete':
        pX,pY = getPts(pLocs)
        plt.scatter(pY,pX, s=2, c='black', alpha=0.25)
    elif call != 'final' and call != 'finalOut':
        colorized = mapColors(pLocs,1,cmap2)
        colorized = mapTransparency(pLocs,colorized,alphaPow)
        plt.imshow(colorized,cmap=cmap2,interpolation='nearest',zorder=2,alpha = popAlpha)
    if call != 'final':
        plt.title("Regional Population Density and Travel Network",size=12)
    else:
        plt.title("Regional Travel Network",size=12)
        
    xTicks = arange(0,cfg['geo']['ncols'],25)
    yTicks = arange(0,cfg['geo']['nrows'],25)
    xLabels = [str(ptToCoords([0,pt],cfg)[1])[0:7] for pt in xTicks]
    yLabels = [str(ptToCoords([pt,0],cfg)[0])[0:7] for pt in yTicks]
    plt.xticks(xTicks, xLabels,rotation=45,size=10)
    plt.yticks(yTicks, yLabels,size=10)
    plt.grid(True)
    
        
    rX,rY = getPts(rLocs)
    plt.scatter(rY,rX, s=250, zorder=3, c = 'none')
    plt.scatter(rY,rX, s=250, c='red', zorder=3, alpha = .5)
    
    bX,bY = getPts(cfg['extras']['permanent'])
    plt.scatter(bY,bX, s=250, zorder=3, c = 'none')
    plt.scatter(bY,bX, s=250, c='blue', zorder=3, alpha = .5)
    
    
    ax2 = plt.subplot(222)
    if distMap:
        plt.imshow(reverseLookup(cfg,rLocs,pLocs,call='plot'),origin='lower')
    plt.title("Expected Travel Time by Region",size = 12)
    plt.xticks(xTicks, xLabels,rotation=45,size=10)
    yLabels = ['' for pt in yTicks]
    plt.yticks(yTicks, yLabels,size=10)
    plt.grid(True)
    
    
    if call == 'final' or call == 'finalOut':
        for x, y, in zip(rY, rX):
            try:
                ax1.annotate(ptsToText([[x,y]],cfg,precision = 7)[0], 
                xy = (x, y), xytext = (-20, 20),
                textcoords = 'offset points', ha = 'left', va = 'bottom',
                bbox = dict(boxstyle = 'round,pad=0.4', fc = 'yellow', alpha = 0.8),
                arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'),
                zorder = 100)
                ax2.texts.append(ax1.texts.pop())
            except:
                None
            plt.suptitle('%s Resource Final Results' % nResource,fontsize =18,y=yNudge)
    
    if call != 'animate' and call != 'final':
        plt.tight_layout()
    else:
        None
        #plt.subplots_adjust(wspace=0.02)
    
    if title != 'null' and call != 'final' and call != 'finalOut':
        plt.suptitle(title,fontsize =18,y=yNudge)
    if stats != 'null':
        plt.xlabel('Mean Travel Time (hrs): %s%sMax Travel Time: %s%sStd Dev: %s' % (stats['mean'],spacer,stats['max'],spacer,stats['std']),
                   x=xNudge,size=14)
    if call != 'animate' and call != 'final':
        plt.show()
    return plt

# %% [markdown]
# ### Starting Conditions

# %%
stats  = {'mean':0,'max':0,'std':0}
pltLocs(pLocs,rLocs,cfg,title = 'Starting Conditions',popAlpha = 1, alphaPow = .25, stats= stats)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-f3558bfd2c37> in <module>()
#       1 stats  = {'mean':0,'max':0,'std':0}
# ----> 2 pltLocs(pLocs,rLocs,cfg,title = 'Starting Conditions',popAlpha = 1, alphaPow = .25, stats= stats)
#
# <ipython-input-34-ec43e3825fbe> in pltLocs(pLocs, rLocs, cfg, stats, title, call, cmap, cmap2, transpose, popAlpha, alphaPow, distMap)
#      77         plt.title("Regional Travel Network",size=12)
#      78
# ---> 79     xTicks = arange(0,cfg['geo']['ncols'],25)
#      80     yTicks = arange(0,cfg['geo']['nrows'],25)
#      81     xLabels = [str(ptToCoords([0,pt],cfg)[1])[0:7] for pt in xTicks]
#
# KeyError: 'geo'

# %% [markdown]
# ### Denaturing Algorithm

# %%
def denature(pLocs,rLocs,meanTilt,cfg,
             tracker=[],
             stopLimit = 50,
             timeLimit = 20000,
             showEvery = 25,
             best = 10000000,
             bestStats=dict()):
    
    """Randomly replaces 1 to n/2 resource locations and keeps if new solution scores better"""
    n = len(rLocs)
    gen = 0
    scores = []
    bestStats = dict()
    t1 = datetime.datetime.now()
    while len(scores)<stopLimit or len(set(scores[-stopLimit:])) != 1:
        newLocs = deepcopy(rLocs)
        ids = sample(range(n),randint(1,int(n/2.+.5)))
        for x in ids:
            if cfg['inCityD']:
                loc = choice(cfg['extras']['postExclusion'])
            else:
                loc = [randint(0,cfg['xSize']-1),randint(0,cfg['ySize']-1-1)]
            newLocs[x] = loc
        stats = getStats(pLocs,newLocs,cfg)
        score = stats['mean']*meanTilt + stats['max']*(1-meanTilt)
        if best > score:
            rLocs = deepcopy(newLocs); bestStats = deepcopy(stats)
            best = score
            tracker.append({'gen':'Denature %s' % gen,'score':score,'stats':deepcopy(stats),'pts':deepcopy(rLocs)})
        if gen%showEvery == 0:
            print "Best: %s   Uni: %s   Gen: %s   Mean: %s   Max: %s   Std: %s   Time: %s" % (best,
                                                                   len(set(scores[-stopLimit:])),
                                                                   gen,bestStats['mean'],
                                                                   bestStats['max'],
                                                                   bestStats['std'],
                                                                   (datetime.datetime.now()-t1).seconds)
        if gen%(showEvery*20) == 0:
            pltLocs(pLocs,rLocs,cfg,bestStats,title='Denaturer Gen %s Optimal Placement' % gen,cmap='Greys_r',cmap2='autumn_r')
        if gen == timeLimit:
            break
        scores.append(best)
        gen += 1
    if gen == timeLimit:
        print "\nGeneration limit reached after %s generations" % timeLimit
    else:
        print "\nStable solution found at generation %s and maintained for %s generations" % (gen-stopLimit,stopLimit)
    pltLocs(pLocs,rLocs,cfg,bestStats,title='Gen %s Optimal Placement' % gen,cmap='Greys_r',cmap2='autumn_r')
    print len(tracker), "improvements made"
    return rLocs,tracker,best,bestStats

# %% [markdown]
# ### Hill Climber Algorithm

# %%
def climb(pLocs,rLocs,meanTilt,cfg,
             tracker=[],
             stopLimit = 50,
             timeLimit = 20000,
             showEvery = 25,
             best = 10000000,
             bestStats=dict()):
    """Randomly nudges 1 to n/2 resources locations and keeps if new solution is better"""
    n = len(rLocs)
    gen = 0
    scores = []
    t1 = datetime.datetime.now()
    while len(scores)<stopLimit or len(set(scores[-stopLimit:])) != 1:
        newLocs = deepcopy(rLocs)
        ids = sample(range(n),randint(1,int(n/2.+.5)))
        for x in ids:
            if cfg['inCityH']:
                loc = choice(cfg['extras']['neighbors'][x])
            else:
                loc = [rLocs[x][0]+randint(-cfg['wander'],cfg['wander']),rLocs[x][1]+randint(-cfg['wander'],cfg['wander'])]
            newLocs[x] = loc
        stats = getStats(pLocs,newLocs,cfg)
        score = stats['mean']*meanTilt + stats['max']*(1-meanTilt)
        if best > score:
            rLocs = deepcopy(newLocs); bestStats = deepcopy(stats)
            best = score
            tracker.append({'gen':'Hill Climber %s' % gen,'score':score,'stats':deepcopy(stats),'pts':deepcopy(rLocs)})
        if gen%showEvery == 0:
            print "Best: %s   Uni: %s   Gen: %s   Mean: %s   Max: %s   Std: %s   Time: %s" % (best,
                                                                   len(set(scores[-stopLimit:])),
                                                                   gen,bestStats['mean'],
                                                                   bestStats['max'],
                                                                   bestStats['std'],
                                                                   (datetime.datetime.now()-t1).seconds)
        if gen%(showEvery*20) == 0:
            pltLocs(pLocs,rLocs,cfg,bestStats,title='Hill Climber Gen %s Optimal Placement' % gen,cmap='Greys_r',cmap2='autumn_r')
        if gen == timeLimit:
            break
        scores.append(best)
        gen += 1
    if gen == timeLimit:
        print "\nGeneration limit reached after %s generations" % timeLimit
    else:
        print "\nStable solution found at generation %s and maintained for %s generations" % (gen-stopLimit,stopLimit)
    pltLocs(pLocs,rLocs,cfg,bestStats,title='Gen %s Optimal Placement' % gen,cmap='Greys_r',cmap2='autumn_r')
    print len(tracker), "improvements made"    
    return rLocs,tracker,best,bestStats

# %% [markdown]
# ### Experiment Results

# %%
#Denature until stable solution is maintained for 30000 generations
stagnantLimit = 2000
best = 10000000
showEvery = 50
cfg['threads'] = 1

rLocs,tracker,best,bestStats = denature(pLocs,rLocs,meanTilt,cfg,
                              stopLimit = stagnantLimit,
                              timeLimit = 'null',
                              showEvery = showEvery,
                              best = best)
# Out:
# Best: 9.99132592332   Uni: 0   Gen: 0   Mean: 4.53422096533   Max: 31.8197457553   Std: 3.0599787561   Time: 1
# Best: 8.2205188782   Uni: 11   Gen: 50   Mean: 2.67733474204   Max: 30.3932554228   Std: 3.21278273213   Time: 96
# Best: 8.19757237054   Uni: 13   Gen: 100   Mean: 2.64865160747   Max: 30.3932554228   Std: 3.21034507957   Time: 179
# Best: 8.17806228468   Uni: 14   Gen: 150   Mean: 2.62426400015   Max: 30.3932554228   Std: 3.19542187872   Time: 263
# Best: 8.17806228468   Uni: 14   Gen: 200   Mean: 2.62426400015   Max: 30.3932554228   Std: 3.19542187872   Time: 345
# Best: 8.1764676168   Uni: 15   Gen: 250   Mean: 2.6222706653   Max: 30.3932554228   Std: 3.20412286601   Time: 427
# Best: 8.1764676168   Uni: 15   Gen: 300   Mean: 2.6222706653   Max: 30.3932554228   Std: 3.20412286601   Time: 511
# Best: 8.1764676168   Uni: 15   Gen: 350   Mean: 2.6222706653   Max: 30.3932554228   Std: 3.20412286601   Time: 593
# Best: 8.16824712883   Uni: 16   Gen: 400   Mean: 2.61199505534   Max: 30.3932554228   Std: 3.20414048319   Time: 677
# Best: 8.16824712883   Uni: 16   Gen: 450   Mean: 2.61199505534   Max: 30.3932554228   Std: 3.20414048319   Time: 760
# Best: 8.16824712883   Uni: 16   Gen: 500   Mean: 2.61199505534   Max: 30.3932554228   Std: 3.20414048319   Time: 843
# Best: 8.16824712883   Uni: 16   Gen: 550   Mean: 2.61199505534   Max: 30.3932554228   Std: 3.20414048319   Time: 926
# Best: 8.16824712883   Uni: 16   Gen: 600   Mean: 2.61199505534   Max: 30.3932554228   Std: 3.20414048319   Time: 1020
# Best: 8.16824712883   Uni: 16   Gen: 650   Mean: 2.61199505534   Max: 30.3932554228   Std: 3.20414048319   Time: 1112
# Best: 8.16824712883   Uni: 16   Gen: 700   Mean: 2.61199505534   Max: 30.3932554228   Std: 3.20414048319   Time: 1204
# Best: 8.16824712883   Uni: 16   Gen: 750   Mean: 2.61199505534   Max: 30.3932554228   Std: 3.20414048319   Time: 1296
# Best: 8.16824712883   Uni: 16   Gen: 800   Mean: 2.61199505534   Max: 30.3932554228   Std: 3.20414048319   Time: 1389
# Best: 8.16824712883   Uni: 16   Gen: 850   Mean: 2.61199505534   Max: 30.3932554228   Std: 3.20414048319   Time: 1481
# Best: 8.15972528791   Uni: 17   Gen: 900   Mean: 2.60134275418   Max: 30.3932554228   Std: 3.2633875359   Time: 1574
# Best: 8.15669343201   Uni: 18   Gen: 950   Mean: 2.5975529343   Max: 30.3932554228   Std: 3.26663373655   Time: 1667
# Best: 8.15669343201   Uni: 18   Gen: 1000   Mean: 2.5975529343   Max: 30.3932554228   Std: 3.26663373655   Time: 1762
# Best: 8.15669343201   Uni: 18   Gen: 1050   Mean: 2.5975529343   Max: 30.3932554228   Std: 3.26663373655   Time: 1871
# Best: 8.15669343201   Uni: 18   Gen: 1100   Mean: 2.5975529343   Max: 30.3932554228   Std: 3.26663373655   Time: 1976
# Best: 8.15669343201   Uni: 18   Gen: 1150   Mean: 2.5975529343   Max: 30.3932554228   Std: 3.26663373655   Time: 2088
# Best: 8.15669343201   Uni: 18   Gen: 1200   Mean: 2.5975529343   Max: 30.3932554228   Std: 3.26663373655   Time: 2199
# Best: 8.15669343201   Uni: 18   Gen: 1250   Mean: 2.5975529343   Max: 30.3932554228   Std: 3.26663373655   Time: 2309
# Best: 8.15669343201   Uni: 18   Gen: 1300   Mean: 2.5975529343   Max: 30.3932554228   Std: 3.26663373655   Time: 2413
# Best: 8.15669343201   Uni: 18   Gen: 1350   Mean: 2.5975529343   Max: 30.3932554228   Std: 3.26663373655   Time: 2519
# Best: 8.15669343201   Uni: 18   Gen: 1400   Mean: 2.5975529343   Max: 30.3932554228   Std: 3.26663373655   Time: 2625
# Best: 8.15397195549   Uni: 19   Gen: 1450   Mean: 2.59415108866   Max: 30.3932554228   Std: 3.25706508823   Time: 2721
# Best: 8.15397195549   Uni: 19   Gen: 1500   Mean: 2.59415108866   Max: 30.3932554228   Std: 3.25706508823   Time: 2814
# Best: 8.15397195549   Uni: 19   Gen: 1550   Mean: 2.59415108866   Max: 30.3932554228   Std: 3.25706508823   Time: 2903
# Best: 8.15397195549   Uni: 19   Gen: 1600   Mean: 2.59415108866   Max: 30.3932554228   Std: 3.25706508823   Time: 2993
# Best: 8.1527533166   Uni: 20   Gen: 1650   Mean: 2.59262779005   Max: 30.3932554228   Std: 3.25502345205   Time: 3082
# Best: 8.14414218036   Uni: 21   Gen: 1700   Mean: 2.58186386975   Max: 30.3932554228   Std: 3.13818141074   Time: 3171
# Best: 8.14414218036   Uni: 21   Gen: 1750   Mean: 2.58186386975   Max: 30.3932554228   Std: 3.13818141074   Time: 3261
# Best: 8.14414218036   Uni: 21   Gen: 1800   Mean: 2.58186386975   Max: 30.3932554228   Std: 3.13818141074   Time: 3350
# Best: 8.14414218036   Uni: 21   Gen: 1850   Mean: 2.58186386975   Max: 30.3932554228   Std: 3.13818141074   Time: 3441
# Best: 8.14414218036   Uni: 21   Gen: 1900   Mean: 2.58186386975   Max: 30.3932554228   Std: 3.13818141074   Time: 3532
# Best: 8.14414218036   Uni: 21   Gen: 1950   Mean: 2.58186386975   Max: 30.3932554228   Std: 3.13818141074   Time: 3622
# Best: 8.14414218036   Uni: 21   Gen: 2000   Mean: 2.58186386975   Max: 30.3932554228   Std: 3.13818141074   Time: 3712
# Best: 8.14414218036   Uni: 11   Gen: 2050   Mean: 2.58186386975   Max: 30.3932554228   Std: 3.13818141074   Time: 3818
# Best: 8.14414218036   Uni: 9   Gen: 2100   Mean: 2.58186386975   Max: 30.3932554228   Std: 3.13818141074   Time: 3908
# Best: 8.14060213693   Uni: 9   Gen: 2150   Mean: 2.57743881546   Max: 30.3932554228   Std: 3.14022539168   Time: 3997
# Best: 8.14060213693   Uni: 9   Gen: 2200   Mean: 2.57743881546   Max: 30.3932554228   Std: 3.14022539168   Time: 4087
# Best: 8.14060213693   Uni: 8   Gen: 2250   Mean: 2.57743881546   Max: 30.3932554228   Std: 3.14022539168   Time: 4177
# Best: 8.1390661173   Uni: 9   Gen: 2300   Mean: 2.57551879092   Max: 30.3932554228   Std: 3.1800016777   Time: 4267
# Best: 8.1390661173   Uni: 9   Gen: 2350   Mean: 2.57551879092   Max: 30.3932554228   Std: 3.1800016777   Time: 4356
# Best: 8.1390661173   Uni: 8   Gen: 2400   Mean: 2.57551879092   Max: 30.3932554228   Std: 3.1800016777   Time: 4446
# Best: 8.1390661173   Uni: 8   Gen: 2450   Mean: 2.57551879092   Max: 30.3932554228   Std: 3.1800016777   Time: 4535
# Best: 8.13904184399   Uni: 9   Gen: 2500   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 4625
# Best: 8.13904184399   Uni: 9   Gen: 2550   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 4715
# Best: 8.13904184399   Uni: 9   Gen: 2600   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 4804
# Best: 8.13904184399   Uni: 9   Gen: 2650   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 4893
# Best: 8.13904184399   Uni: 9   Gen: 2700   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 4982
# Best: 8.13904184399   Uni: 9   Gen: 2750   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 5072
# Best: 8.13904184399   Uni: 9   Gen: 2800   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 5160
# Best: 8.13904184399   Uni: 9   Gen: 2850   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 5249
# Best: 8.13904184399   Uni: 8   Gen: 2900   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 5339
# Best: 8.13904184399   Uni: 7   Gen: 2950   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 5428
# Best: 8.13904184399   Uni: 7   Gen: 3000   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 5517
# Best: 8.13904184399   Uni: 7   Gen: 3050   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 5622
# Best: 8.13904184399   Uni: 7   Gen: 3100   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 5712
# Best: 8.13904184399   Uni: 7   Gen: 3150   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 5801
# Best: 8.13904184399   Uni: 7   Gen: 3200   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 5890
# Best: 8.13904184399   Uni: 7   Gen: 3250   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 5978
# Best: 8.13904184399   Uni: 7   Gen: 3300   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 6068
# Best: 8.13904184399   Uni: 7   Gen: 3350   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 6157
# Best: 8.13904184399   Uni: 7   Gen: 3400   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 6245
# Best: 8.13904184399   Uni: 6   Gen: 3450   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 6334
# Best: 8.13904184399   Uni: 6   Gen: 3500   Mean: 2.57548844928   Max: 30.3932554228   Std: 3.17848321552   Time: 6424
# Best: 8.13729508121   Uni: 7   Gen: 3550   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 6512
# Best: 8.13729508121   Uni: 7   Gen: 3600   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 6602
# Best: 8.13729508121   Uni: 6   Gen: 3650   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 6691
# Best: 8.13729508121   Uni: 5   Gen: 3700   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 6781
# Best: 8.13729508121   Uni: 5   Gen: 3750   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 6871
# Best: 8.13729508121   Uni: 5   Gen: 3800   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 6959
# Best: 8.13729508121   Uni: 5   Gen: 3850   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 7041
# Best: 8.13729508121   Uni: 5   Gen: 3900   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 7124
# Best: 8.13729508121   Uni: 5   Gen: 3950   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 7208
# Best: 8.13729508121   Uni: 5   Gen: 4000   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 7289
# Best: 8.13729508121   Uni: 5   Gen: 4050   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 7374
# Best: 8.13729508121   Uni: 5   Gen: 4100   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 7446
# Best: 8.13729508121   Uni: 4   Gen: 4150   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 7518
# Best: 8.13729508121   Uni: 4   Gen: 4200   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 7590
# Best: 8.13729508121   Uni: 4   Gen: 4250   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 7661
# Best: 8.13729508121   Uni: 3   Gen: 4300   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 7733
# Best: 8.13729508121   Uni: 3   Gen: 4350   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 7806
# Best: 8.13729508121   Uni: 3   Gen: 4400   Mean: 2.5733049958   Max: 30.3932554228   Std: 3.18805313431   Time: 7879
# Best: 8.13685103447   Uni: 4   Gen: 4450   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 7951
# Best: 8.13685103447   Uni: 3   Gen: 4500   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8024
# Best: 8.13685103447   Uni: 3   Gen: 4550   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8096
# Best: 8.13685103447   Uni: 3   Gen: 4600   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8170
# Best: 8.13685103447   Uni: 3   Gen: 4650   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8243
# Best: 8.13685103447   Uni: 3   Gen: 4700   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8315
# Best: 8.13685103447   Uni: 3   Gen: 4750   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8387
# Best: 8.13685103447   Uni: 3   Gen: 4800   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8460
# Best: 8.13685103447   Uni: 3   Gen: 4850   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8532
# Best: 8.13685103447   Uni: 3   Gen: 4900   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8604
# Best: 8.13685103447   Uni: 3   Gen: 4950   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8675
# Best: 8.13685103447   Uni: 3   Gen: 5000   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8747
# Best: 8.13685103447   Uni: 3   Gen: 5050   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8832
# Best: 8.13685103447   Uni: 3   Gen: 5100   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8904
# Best: 8.13685103447   Uni: 3   Gen: 5150   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 8976
# Best: 8.13685103447   Uni: 3   Gen: 5200   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9048
# Best: 8.13685103447   Uni: 3   Gen: 5250   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9120
# Best: 8.13685103447   Uni: 3   Gen: 5300   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9191
# Best: 8.13685103447   Uni: 3   Gen: 5350   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9263
# Best: 8.13685103447   Uni: 3   Gen: 5400   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9335
# Best: 8.13685103447   Uni: 3   Gen: 5450   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9407
# Best: 8.13685103447   Uni: 3   Gen: 5500   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9478
# Best: 8.13685103447   Uni: 2   Gen: 5550   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9550
# Best: 8.13685103447   Uni: 2   Gen: 5600   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9622
# Best: 8.13685103447   Uni: 2   Gen: 5650   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9694
# Best: 8.13685103447   Uni: 2   Gen: 5700   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9766
# Best: 8.13685103447   Uni: 2   Gen: 5750   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9837
# Best: 8.13685103447   Uni: 2   Gen: 5800   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9909
# Best: 8.13685103447   Uni: 2   Gen: 5850   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 9981
# Best: 8.13685103447   Uni: 2   Gen: 5900   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 10054
# Best: 8.13685103447   Uni: 2   Gen: 5950   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 10128
# Best: 8.13685103447   Uni: 2   Gen: 6000   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 10201
# Best: 8.13685103447   Uni: 2   Gen: 6050   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 10287
# Best: 8.13685103447   Uni: 2   Gen: 6100   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 10359
# Best: 8.13685103447   Uni: 2   Gen: 6150   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 10431
# Best: 8.13685103447   Uni: 2   Gen: 6200   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 10503
# Best: 8.13685103447   Uni: 2   Gen: 6250   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 10574
# Best: 8.13685103447   Uni: 2   Gen: 6300   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 10646
# Best: 8.13685103447   Uni: 2   Gen: 6350   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 10718
# Best: 8.13685103447   Uni: 2   Gen: 6400   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 10790
# Stable solution found at generation 4446 and maintained for 2000 generations
# 26 improvements made

# %%
#Hill climb until stable solution is maintained for 3000 generations
cfg['threads'] = 1
stagnantLimit = 4000

rLocs,tracker,best,bestStats = climb(pLocs,rLocs,meanTilt,cfg,
                              stopLimit = stagnantLimit,
                              timeLimit = 'null',
                              showEvery = showEvery,
                              best = best,
                              bestStats = bestStats,
                              tracker = tracker)
# Out:
# Best: 8.13685103447   Uni: 0   Gen: 0   Mean: 2.57274993738   Max: 30.3932554228   Std: 3.14898711567   Time: 1
# Best: 8.13497938328   Uni: 4   Gen: 50   Mean: 2.5704103734   Max: 30.3932554228   Std: 3.14744274537   Time: 83
# Best: 8.13292569993   Uni: 6   Gen: 100   Mean: 2.5678432692   Max: 30.3932554228   Std: 3.14681006393   Time: 150
# Best: 8.12243002374   Uni: 7   Gen: 150   Mean: 2.56995904299   Max: 30.3323139467   Std: 3.14039192308   Time: 219
# Best: 8.11440572135   Uni: 9   Gen: 200   Mean: 2.559928665   Max: 30.3323139467   Std: 3.14438376921   Time: 288
# Best: 8.11405493672   Uni: 10   Gen: 250   Mean: 2.55949018422   Max: 30.3323139467   Std: 3.14469465583   Time: 353
# Best: 8.11403259932   Uni: 11   Gen: 300   Mean: 2.55946226247   Max: 30.3323139467   Std: 3.14756248193   Time: 421
# Best: 8.09981270653   Uni: 15   Gen: 350   Mean: 2.54168739648   Max: 30.3323139467   Std: 3.15255488187   Time: 487
# Best: 8.08726619856   Uni: 17   Gen: 400   Mean: 2.54755032701   Max: 30.2461296848   Std: 3.14155571234   Time: 555
# Best: 8.04431470325   Uni: 19   Gen: 450   Mean: 2.56111313041   Max: 29.9771209946   Std: 3.12829460454   Time: 621
# Best: 8.01271190366   Uni: 23   Gen: 500   Mean: 2.55696143445   Max: 29.8357137805   Std: 3.12911313034   Time: 686
# Best: 8.01175756321   Uni: 24   Gen: 550   Mean: 2.55576850889   Max: 29.8357137805   Std: 3.12825469287   Time: 754
# Best: 7.98241412817   Uni: 25   Gen: 600   Mean: 2.5676545841   Max: 29.6414523044   Std: 3.12277165456   Time: 821
# Best: 7.98135735384   Uni: 28   Gen: 650   Mean: 2.56633361618   Max: 29.6414523044   Std: 3.12149005086   Time: 887
# Best: 7.98045235864   Uni: 30   Gen: 700   Mean: 2.56520237219   Max: 29.6414523044   Std: 3.12034306793   Time: 954
# Best: 7.97250115463   Uni: 34   Gen: 750   Mean: 2.56704730168   Max: 29.5943165664   Std: 3.11689023698   Time: 1021
# Best: 7.968190275   Uni: 35   Gen: 800   Mean: 2.57344263666   Max: 29.5471808284   Std: 3.11391391653   Time: 1087
# Best: 7.96778437197   Uni: 36   Gen: 850   Mean: 2.57293525787   Max: 29.5471808284   Std: 3.11429998064   Time: 1151
# Best: 7.96736586943   Uni: 38   Gen: 900   Mean: 2.56896069519   Max: 29.5609865664   Std: 3.11468982527   Time: 1216
# Best: 7.96736586943   Uni: 38   Gen: 950   Mean: 2.56896069519   Max: 29.5609865664   Std: 3.11468982527   Time: 1280
# Best: 7.96436207895   Uni: 40   Gen: 1000   Mean: 2.56520595709   Max: 29.5609865664   Std: 3.11330981271   Time: 1345
# Best: 7.94687166665   Uni: 45   Gen: 1050   Mean: 2.56691081073   Max: 29.4667150903   Std: 3.1147410371   Time: 1423
# Best: 7.9460583991   Uni: 46   Gen: 1100   Mean: 2.56589422629   Max: 29.4667150903   Std: 3.1122471916   Time: 1491
# Best: 7.93661537052   Uni: 47   Gen: 1150   Mean: 2.57075544056   Max: 29.4000550903   Std: 3.10771532491   Time: 1556
# Best: 7.93343437005   Uni: 50   Gen: 1200   Mean: 2.56677918997   Max: 29.4000550903   Std: 3.10792357331   Time: 1622
# Best: 7.93343437005   Uni: 50   Gen: 1250   Mean: 2.56677918997   Max: 29.4000550903   Std: 3.10792357331   Time: 1689
# Best: 7.93094884539   Uni: 52   Gen: 1300   Mean: 2.56712371866   Max: 29.3862493523   Std: 3.10719422164   Time: 1756
# Best: 7.93094884539   Uni: 52   Gen: 1350   Mean: 2.56712371866   Max: 29.3862493523   Std: 3.10719422164   Time: 1822
# Best: 7.92131625367   Uni: 54   Gen: 1400   Mean: 2.57519941351   Max: 29.3057836143   Std: 3.09999673199   Time: 1890
# Best: 7.89310355181   Uni: 57   Gen: 1450   Mean: 2.5767149707   Max: 29.1586578762   Std: 3.09226033933   Time: 1959
# Best: 7.88496551972   Uni: 58   Gen: 1500   Mean: 2.58320743059   Max: 29.0919978762   Std: 3.08887163116   Time: 2027
# Best: 7.8793395771   Uni: 60   Gen: 1550   Mean: 2.58795893682   Max: 29.0448621382   Std: 3.0845232251   Time: 2093
# Best: 7.87863742127   Uni: 61   Gen: 1600   Mean: 2.58708124203   Max: 29.0448621382   Std: 3.08285754813   Time: 2163
# Best: 7.87863742127   Uni: 61   Gen: 1650   Mean: 2.58708124203   Max: 29.0448621382   Std: 3.08285754813   Time: 2231
# Best: 7.87560774691   Uni: 63   Gen: 1700   Mean: 2.58329414908   Max: 29.0448621382   Std: 3.08137745074   Time: 2301
# Best: 7.87560774691   Uni: 63   Gen: 1750   Mean: 2.58329414908   Max: 29.0448621382   Std: 3.08137745074   Time: 2370
# Best: 6.97782487184   Uni: 69   Gen: 1800   Mean: 2.72161877095   Max: 24.0026492754   Std: 3.00385340226   Time: 2439
# Best: 6.97272311328   Uni: 69   Gen: 1850   Mean: 2.71524157274   Max: 24.0026492754   Std: 2.94754334921   Time: 2508
# Best: 6.97113878212   Uni: 72   Gen: 1900   Mean: 2.71326115879   Max: 24.0026492754   Std: 2.94074453727   Time: 2574
# Best: 6.96308468236   Uni: 73   Gen: 1950   Mean: 2.71842890311   Max: 23.9417077994   Std: 2.93447749656   Time: 2640
# Best: 6.95337757077   Uni: 76   Gen: 2000   Mean: 2.70629501363   Max: 23.9417077994   Std: 2.89926764046   Time: 2706
# Best: 6.9031972154   Uni: 82   Gen: 2050   Mean: 2.68868350392   Max: 23.7612520613   Std: 2.81542756197   Time: 2785
# Best: 6.89990890865   Uni: 85   Gen: 2100   Mean: 2.68457312048   Max: 23.7612520613   Std: 2.81447914241   Time: 2852
# Best: 6.89945650732   Uni: 86   Gen: 2150   Mean: 2.68400761882   Max: 23.7612520613   Std: 2.8198852884   Time: 2917
# Best: 6.89890013413   Uni: 87   Gen: 2200   Mean: 2.68331215233   Max: 23.7612520613   Std: 2.82705346111   Time: 2983
# Best: 6.89815123293   Uni: 89   Gen: 2250   Mean: 2.68237602583   Max: 23.7612520613   Std: 2.82727564282   Time: 3048
# Best: 6.88948660334   Uni: 91   Gen: 2300   Mean: 2.67154523885   Max: 23.7612520613   Std: 2.81700906484   Time: 3115
# Best: 6.88948660334   Uni: 91   Gen: 2350   Mean: 2.67154523885   Max: 23.7612520613   Std: 2.81700906484   Time: 3181
# Best: 6.88928190449   Uni: 92   Gen: 2400   Mean: 2.67128936527   Max: 23.7612520613   Std: 2.81711741965   Time: 3248
# Best: 6.88928190449   Uni: 92   Gen: 2450   Mean: 2.67128936527   Max: 23.7612520613   Std: 2.81711741965   Time: 3315
# Best: 6.88453212466   Uni: 94   Gen: 2500   Mean: 2.66535214049   Max: 23.7612520613   Std: 2.81853876217   Time: 3381
# Best: 6.88449442414   Uni: 95   Gen: 2550   Mean: 2.66530501484   Max: 23.7612520613   Std: 2.81908002019   Time: 3449
# Best: 6.88449442414   Uni: 95   Gen: 2600   Mean: 2.66530501484   Max: 23.7612520613   Std: 2.81908002019   Time: 3515
# Best: 6.88323173565   Uni: 96   Gen: 2650   Mean: 2.67205915423   Max: 23.7279220613   Std: 2.82358409705   Time: 3579
# Best: 6.88323173565   Uni: 96   Gen: 2700   Mean: 2.67205915423   Max: 23.7279220613   Std: 2.82358409705   Time: 3645
# Best: 6.88323173565   Uni: 96   Gen: 2750   Mean: 2.67205915423   Max: 23.7279220613   Std: 2.82358409705   Time: 3712
# Best: 6.88323173565   Uni: 96   Gen: 2800   Mean: 2.67205915423   Max: 23.7279220613   Std: 2.82358409705   Time: 3777
# Best: 6.8801113367   Uni: 97   Gen: 2850   Mean: 2.66815865554   Max: 23.7279220613   Std: 2.81816976407   Time: 3841
# Best: 6.8801113367   Uni: 97   Gen: 2900   Mean: 2.66815865554   Max: 23.7279220613   Std: 2.81816976407   Time: 3908
# Best: 6.87976320704   Uni: 98   Gen: 2950   Mean: 2.66772349347   Max: 23.7279220613   Std: 2.81656839922   Time: 3971
# Best: 6.87892324169   Uni: 99   Gen: 3000   Mean: 2.66667353678   Max: 23.7279220613   Std: 2.81703132546   Time: 4037
# Best: 6.87892324169   Uni: 99   Gen: 3050   Mean: 2.66667353678   Max: 23.7279220613   Std: 2.81703132546   Time: 4114
# Best: 6.87892324169   Uni: 99   Gen: 3100   Mean: 2.66667353678   Max: 23.7279220613   Std: 2.81703132546   Time: 4181
# Best: 6.87771103068   Uni: 100   Gen: 3150   Mean: 2.66515827301   Max: 23.7279220613   Std: 2.81514578895   Time: 4245
# Best: 6.87771103068   Uni: 100   Gen: 3200   Mean: 2.66515827301   Max: 23.7279220613   Std: 2.81514578895   Time: 4309
# Best: 6.87771103068   Uni: 100   Gen: 3250   Mean: 2.66515827301   Max: 23.7279220613   Std: 2.81514578895   Time: 4374
# Best: 6.87771103068   Uni: 100   Gen: 3300   Mean: 2.66515827301   Max: 23.7279220613   Std: 2.81514578895   Time: 4441
# Best: 6.87553418716   Uni: 101   Gen: 3350   Mean: 2.66243721861   Max: 23.7279220613   Std: 2.80955725252   Time: 4506
# Best: 6.87447733923   Uni: 102   Gen: 3400   Mean: 2.6611161587   Max: 23.7279220613   Std: 2.80941680365   Time: 4571
# Best: 6.87447733923   Uni: 102   Gen: 3450   Mean: 2.6611161587   Max: 23.7279220613   Std: 2.80941680365   Time: 4635
# Best: 6.8706340263   Uni: 103   Gen: 3500   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 4698
# Best: 6.8706340263   Uni: 103   Gen: 3550   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 4765
# Best: 6.8706340263   Uni: 103   Gen: 3600   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 4829
# Best: 6.8706340263   Uni: 103   Gen: 3650   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 4895
# Best: 6.8706340263   Uni: 103   Gen: 3700   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 4959
# Best: 6.8706340263   Uni: 103   Gen: 3750   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 5025
# Best: 6.8706340263   Uni: 103   Gen: 3800   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 5090
# Best: 6.8706340263   Uni: 103   Gen: 3850   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 5155
# Best: 6.8706340263   Uni: 103   Gen: 3900   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 5219
# Best: 6.8706340263   Uni: 103   Gen: 3950   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 5284
# Best: 6.8706340263   Uni: 103   Gen: 4000   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 5350
# Best: 6.8706340263   Uni: 100   Gen: 4050   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 5425
# Best: 6.8706340263   Uni: 98   Gen: 4100   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 5491
# Best: 6.8706340263   Uni: 97   Gen: 4150   Mean: 2.65631201755   Max: 23.7279220613   Std: 2.80473751562   Time: 5556
# Best: 6.87003993873   Uni: 96   Gen: 4200   Mean: 2.65556940809   Max: 23.7279220613   Std: 2.80403404916   Time: 5621
# Best: 6.87003993873   Uni: 95   Gen: 4250   Mean: 2.65556940809   Max: 23.7279220613   Std: 2.80403404916   Time: 5686
# Best: 6.87003993873   Uni: 94   Gen: 4300   Mean: 2.65556940809   Max: 23.7279220613   Std: 2.80403404916   Time: 5749
# Best: 6.87003993873   Uni: 90   Gen: 4350   Mean: 2.65556940809   Max: 23.7279220613   Std: 2.80403404916   Time: 5814
# Best: 6.87003483617   Uni: 89   Gen: 4400   Mean: 2.65556302988   Max: 23.7279220613   Std: 2.80492672383   Time: 5879
# Best: 6.87003483617   Uni: 86   Gen: 4450   Mean: 2.65556302988   Max: 23.7279220613   Std: 2.80492672383   Time: 5942
# Best: 6.87003483617   Uni: 83   Gen: 4500   Mean: 2.65556302988   Max: 23.7279220613   Std: 2.80492672383   Time: 6008
# Best: 6.86808800821   Uni: 83   Gen: 4550   Mean: 2.65312949493   Max: 23.7279220613   Std: 2.80281978167   Time: 6073
# Best: 6.86756408239   Uni: 82   Gen: 4600   Mean: 2.65247458765   Max: 23.7279220613   Std: 2.8032554044   Time: 6139
# Best: 6.86756408239   Uni: 80   Gen: 4650   Mean: 2.65247458765   Max: 23.7279220613   Std: 2.8032554044   Time: 6204
# Best: 6.86756408239   Uni: 78   Gen: 4700   Mean: 2.65247458765   Max: 23.7279220613   Std: 2.8032554044   Time: 6268
# Best: 6.86756408239   Uni: 74   Gen: 4750   Mean: 2.65247458765   Max: 23.7279220613   Std: 2.8032554044   Time: 6333
# Best: 6.86756408239   Uni: 73   Gen: 4800   Mean: 2.65247458765   Max: 23.7279220613   Std: 2.8032554044   Time: 6399
# Best: 6.86756408239   Uni: 72   Gen: 4850   Mean: 2.65247458765   Max: 23.7279220613   Std: 2.8032554044   Time: 6464
# Best: 6.86756408239   Uni: 70   Gen: 4900   Mean: 2.65247458765   Max: 23.7279220613   Std: 2.8032554044   Time: 6529
# Best: 6.86756408239   Uni: 70   Gen: 4950   Mean: 2.65247458765   Max: 23.7279220613   Std: 2.8032554044   Time: 6593
# Best: 6.86756408239   Uni: 68   Gen: 5000   Mean: 2.65247458765   Max: 23.7279220613   Std: 2.8032554044   Time: 6657
# Best: 6.86756408239   Uni: 63   Gen: 5050   Mean: 2.65247458765   Max: 23.7279220613   Std: 2.8032554044   Time: 6736
# Best: 6.86190309269   Uni: 65   Gen: 5100   Mean: 2.64539835054   Max: 23.7279220613   Std: 2.79774255803   Time: 6801
# Best: 6.85562771743   Uni: 65   Gen: 5150   Mean: 2.63755413145   Max: 23.7279220613   Std: 2.79313785568   Time: 6867
# Best: 6.85562771743   Uni: 62   Gen: 5200   Mean: 2.63755413145   Max: 23.7279220613   Std: 2.79313785568   Time: 6933
# Best: 6.85562771743   Uni: 62   Gen: 5250   Mean: 2.63755413145   Max: 23.7279220613   Std: 2.79313785568   Time: 6999
# Best: 6.85562771743   Uni: 60   Gen: 5300   Mean: 2.63755413145   Max: 23.7279220613   Std: 2.79313785568   Time: 7064
# Best: 6.85036841761   Uni: 63   Gen: 5350   Mean: 2.63098000668   Max: 23.7279220613   Std: 2.78746138024   Time: 7130
# Best: 6.85036841761   Uni: 61   Gen: 5400   Mean: 2.63098000668   Max: 23.7279220613   Std: 2.78746138024   Time: 7195
# Best: 6.84934157488   Uni: 59   Gen: 5450   Mean: 2.62969645327   Max: 23.7279220613   Std: 2.78766792427   Time: 7260
# Best: 6.84934157488   Uni: 58   Gen: 5500   Mean: 2.62969645327   Max: 23.7279220613   Std: 2.78766792427   Time: 7323
# Best: 6.83291899721   Uni: 58   Gen: 5550   Mean: 2.60916823118   Max: 23.7279220613   Std: 2.77841969487   Time: 7387
# Best: 6.83291899721   Uni: 57   Gen: 5600   Mean: 2.60916823118   Max: 23.7279220613   Std: 2.77841969487   Time: 7450
# Best: 6.83291899721   Uni: 57   Gen: 5650   Mean: 2.60916823118   Max: 23.7279220613   Std: 2.77841969487   Time: 7514
# Best: 6.82842439865   Uni: 56   Gen: 5700   Mean: 2.60354998299   Max: 23.7279220613   Std: 2.77623269605   Time: 7578
# Best: 6.82842439865   Uni: 56   Gen: 5750   Mean: 2.60354998299   Max: 23.7279220613   Std: 2.77623269605   Time: 7642
# Best: 6.82842439865   Uni: 50   Gen: 5800   Mean: 2.60354998299   Max: 23.7279220613   Std: 2.77623269605   Time: 7704
# Best: 6.8208991005   Uni: 50   Gen: 5850   Mean: 2.59414336029   Max: 23.7279220613   Std: 2.77126782542   Time: 7768
# Best: 6.8208991005   Uni: 48   Gen: 5900   Mean: 2.59414336029   Max: 23.7279220613   Std: 2.77126782542   Time: 7832
# Best: 6.8208991005   Uni: 47   Gen: 5950   Mean: 2.59414336029   Max: 23.7279220613   Std: 2.77126782542   Time: 7896
# Best: 6.80927808283   Uni: 44   Gen: 6000   Mean: 2.5796170882   Max: 23.7279220613   Std: 2.7668924114   Time: 7960
# Best: 6.80927808283   Uni: 39   Gen: 6050   Mean: 2.5796170882   Max: 23.7279220613   Std: 2.7668924114   Time: 8037
# Best: 6.80927808283   Uni: 36   Gen: 6100   Mean: 2.5796170882   Max: 23.7279220613   Std: 2.7668924114   Time: 8101
# Best: 6.80927808283   Uni: 35   Gen: 6150   Mean: 2.5796170882   Max: 23.7279220613   Std: 2.7668924114   Time: 8166
# Best: 6.80927808283   Uni: 34   Gen: 6200   Mean: 2.5796170882   Max: 23.7279220613   Std: 2.7668924114   Time: 8230
# Best: 6.80350845689   Uni: 33   Gen: 6250   Mean: 2.57240505578   Max: 23.7279220613   Std: 2.76481203369   Time: 8295
# Best: 6.80350845689   Uni: 31   Gen: 6300   Mean: 2.57240505578   Max: 23.7279220613   Std: 2.76481203369   Time: 8357
# Best: 6.8023427022   Uni: 32   Gen: 6350   Mean: 2.57094786242   Max: 23.7279220613   Std: 2.7658156788   Time: 8423
# Best: 6.79857970306   Uni: 32   Gen: 6400   Mean: 2.56624411349   Max: 23.7279220613   Std: 2.76578299483   Time: 8488
# Best: 6.79857970306   Uni: 32   Gen: 6450   Mean: 2.56624411349   Max: 23.7279220613   Std: 2.76578299483   Time: 8553
# Best: 6.79180209718   Uni: 31   Gen: 6500   Mean: 2.55777210614   Max: 23.7279220613   Std: 2.76662907093   Time: 8619
# Best: 6.79180209718   Uni: 30   Gen: 6550   Mean: 2.55777210614   Max: 23.7279220613   Std: 2.76662907093   Time: 8683
# Best: 6.78161083601   Uni: 31   Gen: 6600   Mean: 2.54503302968   Max: 23.7279220613   Std: 2.76888516361   Time: 8749
# Best: 6.78161083601   Uni: 30   Gen: 6650   Mean: 2.54503302968   Max: 23.7279220613   Std: 2.76888516361   Time: 8812
# Best: 6.78161083601   Uni: 30   Gen: 6700   Mean: 2.54503302968   Max: 23.7279220613   Std: 2.76888516361   Time: 8875
# Best: 6.76978145209   Uni: 32   Gen: 6750   Mean: 2.53024629978   Max: 23.7279220613   Std: 2.77289993843   Time: 8939
# Best: 6.76978145209   Uni: 32   Gen: 6800   Mean: 2.53024629978   Max: 23.7279220613   Std: 2.77289993843   Time: 9002
# Best: 6.76571501994   Uni: 32   Gen: 6850   Mean: 2.52516325959   Max: 23.7279220613   Std: 2.77674044801   Time: 9067
# Best: 6.76571501994   Uni: 32   Gen: 6900   Mean: 2.52516325959   Max: 23.7279220613   Std: 2.77674044801   Time: 9131
# Best: 6.75948825117   Uni: 35   Gen: 6950   Mean: 2.51737979864   Max: 23.7279220613   Std: 2.78658574991   Time: 9196
# Best: 6.75774880738   Uni: 35   Gen: 7000   Mean: 2.5152054939   Max: 23.7279220613   Std: 2.78172122377   Time: 9260
# Best: 6.75115543872   Uni: 37   Gen: 7050   Mean: 2.50696378307   Max: 23.7279220613   Std: 2.78518756868   Time: 9337
# Best: 6.75115543872   Uni: 37   Gen: 7100   Mean: 2.50696378307   Max: 23.7279220613   Std: 2.78518756868   Time: 9401
# Best: 6.75115543872   Uni: 36   Gen: 7150   Mean: 2.50696378307   Max: 23.7279220613   Std: 2.78518756868   Time: 9464
# Best: 6.74773630779   Uni: 37   Gen: 7200   Mean: 2.5026898694   Max: 23.7279220613   Std: 2.78543518925   Time: 9530
# Best: 6.74773630779   Uni: 38   Gen: 7250   Mean: 2.5026898694   Max: 23.7279220613   Std: 2.78543518925   Time: 9595
# Best: 6.74703194949   Uni: 39   Gen: 7300   Mean: 2.50180942153   Max: 23.7279220613   Std: 2.78464092693   Time: 9660
# Best: 6.74703194949   Uni: 38   Gen: 7350   Mean: 2.50180942153   Max: 23.7279220613   Std: 2.78464092693   Time: 9724
# Best: 6.74529562437   Uni: 38   Gen: 7400   Mean: 2.49963901513   Max: 23.7279220613   Std: 2.78512366228   Time: 9788
# Best: 6.7421690887   Uni: 40   Gen: 7450   Mean: 2.49573084554   Max: 23.7279220613   Std: 2.80727868943   Time: 9853
# Best: 6.73764145898   Uni: 41   Gen: 7500   Mean: 2.49007130839   Max: 23.7279220613   Std: 2.78679629087   Time: 9919
# Best: 6.73734575117   Uni: 42   Gen: 7550   Mean: 2.48970167363   Max: 23.7279220613   Std: 2.78722447788   Time: 9983
# Best: 6.73734575117   Uni: 42   Gen: 7600   Mean: 2.48970167363   Max: 23.7279220613   Std: 2.78722447788   Time: 10048
# Best: 6.73523301221   Uni: 43   Gen: 7650   Mean: 2.48706074992   Max: 23.7279220613   Std: 2.78621925381   Time: 10114
# Best: 6.73385110542   Uni: 45   Gen: 7700   Mean: 2.48533336644   Max: 23.7279220613   Std: 2.79084117124   Time: 10180
# Best: 6.73385110542   Uni: 45   Gen: 7750   Mean: 2.48533336644   Max: 23.7279220613   Std: 2.79084117124   Time: 10244
# Best: 6.72574003231   Uni: 47   Gen: 7800   Mean: 2.47519452505   Max: 23.7279220613   Std: 2.79483698563   Time: 10309
# Best: 6.72574003231   Uni: 47   Gen: 7850   Mean: 2.47519452505   Max: 23.7279220613   Std: 2.79483698563   Time: 10373
# Best: 6.72574003231   Uni: 47   Gen: 7900   Mean: 2.47519452505   Max: 23.7279220613   Std: 2.79483698563   Time: 10436
# Best: 6.72272421383   Uni: 49   Gen: 7950   Mean: 2.47142475196   Max: 23.7279220613   Std: 2.80318107686   Time: 10502
# Best: 6.72272421383   Uni: 49   Gen: 8000   Mean: 2.47142475196   Max: 23.7279220613   Std: 2.80318107686   Time: 10568
# Best: 6.72137543222   Uni: 50   Gen: 8050   Mean: 2.46973877494   Max: 23.7279220613   Std: 2.81420492697   Time: 10647
# Best: 6.71800016143   Uni: 53   Gen: 8100   Mean: 2.46551968645   Max: 23.7279220613   Std: 2.82375529918   Time: 10714
# Best: 6.71800016143   Uni: 53   Gen: 8150   Mean: 2.46551968645   Max: 23.7279220613   Std: 2.82375529918   Time: 10781
# Best: 6.71800016143   Uni: 52   Gen: 8200   Mean: 2.46551968645   Max: 23.7279220613   Std: 2.82375529918   Time: 10846
# Best: 6.71784691877   Uni: 53   Gen: 8250   Mean: 2.46532813313   Max: 23.7279220613   Std: 2.82720410281   Time: 10912
# Best: 6.71784691877   Uni: 53   Gen: 8300   Mean: 2.46532813313   Max: 23.7279220613   Std: 2.82720410281   Time: 10978
# Best: 6.71784691877   Uni: 53   Gen: 8350   Mean: 2.46532813313   Max: 23.7279220613   Std: 2.82720410281   Time: 11044
# Best: 6.71776907171   Uni: 53   Gen: 8400   Mean: 2.46523082431   Max: 23.7279220613   Std: 2.82809915423   Time: 11110
# Best: 6.71776907171   Uni: 53   Gen: 8450   Mean: 2.46523082431   Max: 23.7279220613   Std: 2.82809915423   Time: 11176
# Best: 6.71776907171   Uni: 53   Gen: 8500   Mean: 2.46523082431   Max: 23.7279220613   Std: 2.82809915423   Time: 11241
# Best: 6.71776907171   Uni: 52   Gen: 8550   Mean: 2.46523082431   Max: 23.7279220613   Std: 2.82809915423   Time: 11308
# Best: 6.71776907171   Uni: 51   Gen: 8600   Mean: 2.46523082431   Max: 23.7279220613   Std: 2.82809915423   Time: 11374
# Best: 6.71776907171   Uni: 51   Gen: 8650   Mean: 2.46523082431   Max: 23.7279220613   Std: 2.82809915423   Time: 11439
# Best: 6.71776907171   Uni: 51   Gen: 8700   Mean: 2.46523082431   Max: 23.7279220613   Std: 2.82809915423   Time: 11506
# Best: 6.71749915388   Uni: 52   Gen: 8750   Mean: 2.46489342701   Max: 23.7279220613   Std: 2.81440245848   Time: 11571
# Best: 6.71676599625   Uni: 53   Gen: 8800   Mean: 2.46397697998   Max: 23.7279220613   Std: 2.82391003626   Time: 11636
# Best: 6.71676599625   Uni: 53   Gen: 8850   Mean: 2.46397697998   Max: 23.7279220613   Std: 2.82391003626   Time: 11700
# Best: 6.71634571753   Uni: 54   Gen: 8900   Mean: 2.46345163159   Max: 23.7279220613   Std: 2.82409583432   Time: 11766
# Best: 6.71634571753   Uni: 54   Gen: 8950   Mean: 2.46345163159   Max: 23.7279220613   Std: 2.82409583432   Time: 11831
# Best: 6.71634571753   Uni: 54   Gen: 9000   Mean: 2.46345163159   Max: 23.7279220613   Std: 2.82409583432   Time: 11895
# Best: 6.71381541482   Uni: 55   Gen: 9050   Mean: 2.46028875319   Max: 23.7279220613   Std: 2.83411343339   Time: 11971
# Best: 6.71381541482   Uni: 52   Gen: 9100   Mean: 2.46028875319   Max: 23.7279220613   Std: 2.83411343339   Time: 12036
# Best: 6.71381541482   Uni: 51   Gen: 9150   Mean: 2.46028875319   Max: 23.7279220613   Std: 2.83411343339   Time: 12099
# Best: 6.71381541482   Uni: 51   Gen: 9200   Mean: 2.46028875319   Max: 23.7279220613   Std: 2.83411343339   Time: 12161
# Best: 6.71381541482   Uni: 51   Gen: 9250   Mean: 2.46028875319   Max: 23.7279220613   Std: 2.83411343339   Time: 12223
# Best: 6.71381541482   Uni: 51   Gen: 9300   Mean: 2.46028875319   Max: 23.7279220613   Std: 2.83411343339   Time: 12285
# Best: 6.71381541482   Uni: 48   Gen: 9350   Mean: 2.46028875319   Max: 23.7279220613   Std: 2.83411343339   Time: 12346
# Best: 6.71370598144   Uni: 49   Gen: 9400   Mean: 2.46015196147   Max: 23.7279220613   Std: 2.83088569902   Time: 12407
# Best: 6.71370598144   Uni: 48   Gen: 9450   Mean: 2.46015196147   Max: 23.7279220613   Std: 2.83088569902   Time: 12470
# Best: 6.71370598144   Uni: 48   Gen: 9500   Mean: 2.46015196147   Max: 23.7279220613   Std: 2.83088569902   Time: 12533
# Best: 6.71370598144   Uni: 46   Gen: 9550   Mean: 2.46015196147   Max: 23.7279220613   Std: 2.83088569902   Time: 12596
# Best: 6.71362397993   Uni: 47   Gen: 9600   Mean: 2.46004945958   Max: 23.7279220613   Std: 2.83098314905   Time: 12659
# Best: 6.71362397993   Uni: 47   Gen: 9650   Mean: 2.46004945958   Max: 23.7279220613   Std: 2.83098314905   Time: 12720
# Best: 6.71362397993   Uni: 46   Gen: 9700   Mean: 2.46004945958   Max: 23.7279220613   Std: 2.83098314905   Time: 12783
# Best: 6.71362397993   Uni: 46   Gen: 9750   Mean: 2.46004945958   Max: 23.7279220613   Std: 2.83098314905   Time: 12846
# Best: 6.71362397993   Uni: 46   Gen: 9800   Mean: 2.46004945958   Max: 23.7279220613   Std: 2.83098314905   Time: 12907
# Best: 6.71339900992   Uni: 46   Gen: 9850   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 12969
# Best: 6.71339900992   Uni: 46   Gen: 9900   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13032
# Best: 6.71339900992   Uni: 46   Gen: 9950   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13095
# Best: 6.71339900992   Uni: 45   Gen: 10000   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13158
# Best: 6.71339900992   Uni: 45   Gen: 10050   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13234
# Best: 6.71339900992   Uni: 45   Gen: 10100   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13298
# Best: 6.71339900992   Uni: 45   Gen: 10150   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13361
# Best: 6.71339900992   Uni: 45   Gen: 10200   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13424
# Best: 6.71339900992   Uni: 44   Gen: 10250   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13486
# Best: 6.71339900992   Uni: 44   Gen: 10300   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13549
# Best: 6.71339900992   Uni: 43   Gen: 10350   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13611
# Best: 6.71339900992   Uni: 42   Gen: 10400   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13675
# Best: 6.71339900992   Uni: 42   Gen: 10450   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13738
# Best: 6.71339900992   Uni: 41   Gen: 10500   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13802
# Best: 6.71339900992   Uni: 41   Gen: 10550   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13865
# Best: 6.71339900992   Uni: 40   Gen: 10600   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13929
# Best: 6.71339900992   Uni: 40   Gen: 10650   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 13992
# Best: 6.71339900992   Uni: 40   Gen: 10700   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14054
# Best: 6.71339900992   Uni: 38   Gen: 10750   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14117
# Best: 6.71339900992   Uni: 38   Gen: 10800   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14180
# Best: 6.71339900992   Uni: 37   Gen: 10850   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14241
# Best: 6.71339900992   Uni: 37   Gen: 10900   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14304
# Best: 6.71339900992   Uni: 33   Gen: 10950   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14366
# Best: 6.71339900992   Uni: 32   Gen: 11000   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14427
# Best: 6.71339900992   Uni: 30   Gen: 11050   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14500
# Best: 6.71339900992   Uni: 30   Gen: 11100   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14560
# Best: 6.71339900992   Uni: 30   Gen: 11150   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14621
# Best: 6.71339900992   Uni: 28   Gen: 11200   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14683
# Best: 6.71339900992   Uni: 28   Gen: 11250   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14744
# Best: 6.71339900992   Uni: 27   Gen: 11300   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14806
# Best: 6.71339900992   Uni: 27   Gen: 11350   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14868
# Best: 6.71339900992   Uni: 26   Gen: 11400   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14928
# Best: 6.71339900992   Uni: 24   Gen: 11450   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 14989
# Best: 6.71339900992   Uni: 22   Gen: 11500   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15049
# Best: 6.71339900992   Uni: 21   Gen: 11550   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15110
# Best: 6.71339900992   Uni: 21   Gen: 11600   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15171
# Best: 6.71339900992   Uni: 20   Gen: 11650   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15232
# Best: 6.71339900992   Uni: 18   Gen: 11700   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15293
# Best: 6.71339900992   Uni: 18   Gen: 11750   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15353
# Best: 6.71339900992   Uni: 16   Gen: 11800   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15414
# Best: 6.71339900992   Uni: 16   Gen: 11850   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15474
# Best: 6.71339900992   Uni: 16   Gen: 11900   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15535
# Best: 6.71339900992   Uni: 14   Gen: 11950   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15595
# Best: 6.71339900992   Uni: 14   Gen: 12000   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15655
# Best: 6.71339900992   Uni: 13   Gen: 12050   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15726
# Best: 6.71339900992   Uni: 10   Gen: 12100   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15787
# Best: 6.71339900992   Uni: 10   Gen: 12150   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15848
# Best: 6.71339900992   Uni: 10   Gen: 12200   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15909
# Best: 6.71339900992   Uni: 9   Gen: 12250   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 15970
# Best: 6.71339900992   Uni: 9   Gen: 12300   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 16030
# Best: 6.71339900992   Uni: 9   Gen: 12350   Mean: 2.45976824706   Max: 23.7279220613   Std: 2.83557640624   Time: 16093
# Best: 6.71335919154   Uni: 9   Gen: 12400   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16154
# Best: 6.71335919154   Uni: 9   Gen: 12450   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16213
# Best: 6.71335919154   Uni: 9   Gen: 12500   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16273
# Best: 6.71335919154   Uni: 9   Gen: 12550   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16335
# Best: 6.71335919154   Uni: 9   Gen: 12600   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16396
# Best: 6.71335919154   Uni: 9   Gen: 12650   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16457
# Best: 6.71335919154   Uni: 9   Gen: 12700   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16518
# Best: 6.71335919154   Uni: 8   Gen: 12750   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16579
# Best: 6.71335919154   Uni: 7   Gen: 12800   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16640
# Best: 6.71335919154   Uni: 7   Gen: 12850   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16702
# Best: 6.71335919154   Uni: 6   Gen: 12900   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16763
# Best: 6.71335919154   Uni: 6   Gen: 12950   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16824
# Best: 6.71335919154   Uni: 6   Gen: 13000   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16886
# Best: 6.71335919154   Uni: 5   Gen: 13050   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 16962
# Best: 6.71335919154   Uni: 5   Gen: 13100   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17023
# Best: 6.71335919154   Uni: 5   Gen: 13150   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17083
# Best: 6.71335919154   Uni: 5   Gen: 13200   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17144
# Best: 6.71335919154   Uni: 5   Gen: 13250   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17206
# Best: 6.71335919154   Uni: 5   Gen: 13300   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17269
# Best: 6.71335919154   Uni: 5   Gen: 13350   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17330
# Best: 6.71335919154   Uni: 4   Gen: 13400   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17392
# Best: 6.71335919154   Uni: 4   Gen: 13450   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17452
# Best: 6.71335919154   Uni: 4   Gen: 13500   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17513
# Best: 6.71335919154   Uni: 4   Gen: 13550   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17573
# Best: 6.71335919154   Uni: 3   Gen: 13600   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17635
# Best: 6.71335919154   Uni: 3   Gen: 13650   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17697
# Best: 6.71335919154   Uni: 3   Gen: 13700   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17758
# Best: 6.71335919154   Uni: 3   Gen: 13750   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17819
# Best: 6.71335919154   Uni: 3   Gen: 13800   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17879
# Best: 6.71335919154   Uni: 2   Gen: 13850   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 17940
# Best: 6.71335919154   Uni: 2   Gen: 13900   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18002
# Best: 6.71335919154   Uni: 2   Gen: 13950   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18061
# Best: 6.71335919154   Uni: 2   Gen: 14000   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18123
# Best: 6.71335919154   Uni: 2   Gen: 14050   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18197
# Best: 6.71335919154   Uni: 2   Gen: 14100   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18259
# Best: 6.71335919154   Uni: 2   Gen: 14150   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18321
# Best: 6.71335919154   Uni: 2   Gen: 14200   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18382
# Best: 6.71335919154   Uni: 2   Gen: 14250   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18443
# Best: 6.71335919154   Uni: 2   Gen: 14300   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18504
# Best: 6.71335919154   Uni: 2   Gen: 14350   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18565
# Best: 6.71335919154   Uni: 2   Gen: 14400   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18626
# Best: 6.71335919154   Uni: 2   Gen: 14450   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18687
# Best: 6.71335919154   Uni: 2   Gen: 14500   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18748
# Best: 6.71335919154   Uni: 2   Gen: 14550   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18808
# Best: 6.71335919154   Uni: 2   Gen: 14600   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18869
# Best: 6.71335919154   Uni: 2   Gen: 14650   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18930
# Best: 6.71335919154   Uni: 2   Gen: 14700   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 18992
# Best: 6.71335919154   Uni: 2   Gen: 14750   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19053
# Best: 6.71335919154   Uni: 2   Gen: 14800   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19115
# Best: 6.71335919154   Uni: 2   Gen: 14850   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19175
# Best: 6.71335919154   Uni: 2   Gen: 14900   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19236
# Best: 6.71335919154   Uni: 2   Gen: 14950   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19297
# Best: 6.71335919154   Uni: 2   Gen: 15000   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19357
# Best: 6.71335919154   Uni: 2   Gen: 15050   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19430
# Best: 6.71335919154   Uni: 2   Gen: 15100   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19490
# Best: 6.71335919154   Uni: 2   Gen: 15150   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19551
# Best: 6.71335919154   Uni: 2   Gen: 15200   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19612
# Best: 6.71335919154   Uni: 2   Gen: 15250   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19674
# Best: 6.71335919154   Uni: 2   Gen: 15300   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19737
# Best: 6.71335919154   Uni: 2   Gen: 15350   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19798
# Best: 6.71335919154   Uni: 2   Gen: 15400   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19860
# Best: 6.71335919154   Uni: 2   Gen: 15450   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19921
# Best: 6.71335919154   Uni: 2   Gen: 15500   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 19982
# Best: 6.71335919154   Uni: 2   Gen: 15550   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20044
# Best: 6.71335919154   Uni: 2   Gen: 15600   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20105
# Best: 6.71335919154   Uni: 2   Gen: 15650   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20166
# Best: 6.71335919154   Uni: 2   Gen: 15700   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20226
# Best: 6.71335919154   Uni: 2   Gen: 15750   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20287
# Best: 6.71335919154   Uni: 2   Gen: 15800   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20348
# Best: 6.71335919154   Uni: 2   Gen: 15850   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20409
# Best: 6.71335919154   Uni: 2   Gen: 15900   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20470
# Best: 6.71335919154   Uni: 2   Gen: 15950   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20531
# Best: 6.71335919154   Uni: 2   Gen: 16000   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20592
# Best: 6.71335919154   Uni: 2   Gen: 16050   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20665
# Best: 6.71335919154   Uni: 2   Gen: 16100   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20727
# Best: 6.71335919154   Uni: 2   Gen: 16150   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20789
# Best: 6.71335919154   Uni: 2   Gen: 16200   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20851
# Best: 6.71335919154   Uni: 2   Gen: 16250   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20912
# Best: 6.71335919154   Uni: 2   Gen: 16300   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 20972
# Best: 6.71335919154   Uni: 2   Gen: 16350   Mean: 2.45971847409   Max: 23.7279220613   Std: 2.83573958704   Time: 21034
# Stable solution found at generation 12377 and maintained for 4000 generations
# 190 improvements made

# %%
def animateMaps(pLocs,tracker,cfg,cmap='gist_earth',cmap2='autumn'):
    length = len(tracker)
    fig = plt.figure(figsize=(figSize,figSize))
        
    def animate(i):
        pltLocs(pLocs,
                   tracker[i]['pts'],
                   cfg,
                   stats=tracker[i]['stats'],
                   title='Gen %s Optimal Placement' % tracker[i]['gen'],
                   call='animate',
                   cmap=cmap,
                   cmap2=cmap2)
    
    anim = animation.FuncAnimation(fig,animate,frames=length,interval=200, blit=False)
    fileName = 'mapOptimization'
    #print "Generating", fileName, "gif animation"
    #anim.save(fileName+'.gif', writer='imagemagick', fps=1)
    #sleep(3)
    print "Generating", fileName, "mp4 video"
    writer = animation.writers['ffmpeg'](fps=5)
    anim.save(fileName+'.mp4',writer=writer,dpi=250)
    return anim,fileName

# %%
anim,fileName = animateMaps(pLocs,tracker,cfg)
#display_animation(anim,fileName)
# Out:
# Generating mapOptimization mp4 video

# %% [raw]
# © 2014 James Schlitt
